# %% [markdown]
# # Creation of E/Z dataset

# %% [markdown]
# ## Import section

# %%
import os
import pickle
from builtins import int

# %% [markdown]
# ## Loading of dataset.
#
# choice: rs dataset as most datasets with only one double bond with e/z label

# %%
mode = 'val'
with open(os.path.join("hyperoptimization/src/rs/raw/", f"{mode}.pickle"), 'rb') as f:
    df = pickle.load(f)

# %%
df
# Out:
#                                           ID  \
# 0      Br[C@@]1(c2cccc(-c3ccccc3)c2)C=CC=CC1
# 1      Br[C@@]1(c2cccc(-c3ccccc3)c2)C=CC=CC1
# 2      Br[C@@]1(c2cccc(-c3ccccc3)c2)C=CC=CC1
# 3      Br[C@@]1(c2cccc(-c3ccccc3)c2)C=CC=CC1
# 4      Br[C@@]1(c2cccc(-c3ccccc3)c2)C=CC=CC1
# ...                                      ...
# 70094              c1csc(CNCC[C@H]2CCCNC2)n1
# 70095              c1csc(CNCC[C@H]2CCCNC2)n1
# 70096              c1csc(CNCC[C@H]2CCCNC2)n1
# 70097              c1csc(CNCC[C@H]2CCCNC2)n1
# 70098              c1csc(CNCC[C@H]2CCCNC2)n1
#
#                          SMILES_nostereo  \
# 0      BrC1(c2cccc(-c3ccccc3)c2)C=CC=CC1
# 1      BrC1(c2cccc(-c3ccccc3)c2)C=CC=CC1
# 2      BrC1(c2cccc(-c3ccccc3)c2)C=CC=CC1
# 3      BrC1(c2cccc(-c3ccccc3)c2)C=CC=CC1
# 4      BrC1(c2cccc(-c3ccccc3)c2)C=CC=CC1
# ...                                  ...
# 70094              c1csc(CNCCC2CCCNC2)n1
# 70095              c1csc(CNCCC2CCCNC2)n1
# 70096              c1csc(CNCCC2CCCNC2)n1
# 70097              c1csc(CNCCC2CCCNC2)n1
# 70098              c1csc(CNCCC2CCCNC2)n1
#
#                                rdkit_mol_cistrans_stereo RS_label  \
# 0      <rdkit.Chem.rdchem.Mol object at 0x000001C12B5...        R
# 1      <rdkit.Chem.rdchem.Mol object at 0x000001C12A8...        R
# 2      <rdkit.Chem.rdchem.Mol object at 0x000001C12A8...        R
# 3      <rdkit.Chem.rdchem.Mol object at 0x000001C12A8...        R
# 4      <rdkit.Chem.rdchem.Mol object at 0x000001C12A8...        R
# ...                                                  ...      ...
# 70094  <rdkit.Chem.rdchem.Mol object at 0x000001C1613...        R
# 70095  <rdkit.Chem.rdchem.Mol object at 0x000001C1613...        R
# 70096  <rdkit.Chem.rdchem.Mol object at 0x000001C1613...        R
# 70097  <rdkit.Chem.rdchem.Mol object at 0x000001C1613...        R
# 70098  <rdkit.Chem.rdchem.Mol object at 0x000001C1613...        R
#
#        RS_label_binary
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 70094                0
# 70095                0
# 70096                0
# 70097                0
# 70098                0
#
# [70099 rows x 5 columns]

# %% [markdown]
# ## Filtering only molecules with one double bond that is a stereocenter (and has 4 constituents)

# %%
def filter_has_one_marked_stereo(df_entry, smiles_name: str = 'ID') -> bool:
    from ptgnn.features.chienn.molecule3d import smiles_to_3d_mol
    from rdkit import Chem

    # unpack passed object
    idx, entry = df_entry

    # define allowed stereo types
    allowed_stereo = [
        Chem.rdchem.BondStereo.STEREOZ,
        Chem.rdchem.BondStereo.STEREOE
    ]

    # extract smiles string
    smiles = entry[smiles_name]

    # get molecule
    molecule = smiles_to_3d_mol(
        smiles=smiles,
        max_number_of_atoms=100,
        max_number_of_attempts=100
    )
    if molecule is None:
        return idx, df_entry, -1

    # determine whether molecule has exactly one double bond with marked E/Z
    from rdkit import Chem
    bonds = [
        bond
        for bond in molecule.GetBonds()
        if (bond.GetBondType() == Chem.rdchem.BondType.DOUBLE) and
           (bond.GetStereo() in allowed_stereo) and
           (bond.GetBeginAtom().GetDegree() == 3) and
           (bond.GetEndAtom().GetDegree() == 3) # reduces to 1/6th of items with previous ones
    ]

    #if len(bonds) == 1:
    #    entry['EZ_label'] = "E" if bonds[0].GetStereo() == Chem.rdchem.BondStereo.STEREOE else "Z"
    #    entry['EZ_label_binary'] = 1 if bonds[0].GetStereo() == Chem.rdchem.BondStereo.STEREOE else 0

    return idx, entry, len(bonds)

# %%
from tqdm import tqdm
from multiprocess.pool import Pool

with Pool(processes=os.cpu_count()-4) as p:
    df_collection = list(p.imap(
        filter_has_one_marked_stereo,
        tqdm(df.iterrows(), total=len(df))
    ))
# Out:
# 100%|██████████| 70099/70099 [05:58<00:00, 195.69it/s]

# %%
df_collection
# Out:
# [(0,
#   ID                                       Br[C@@]1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   SMILES_nostereo                              BrC1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 0, dtype: object,
#   0),
#  (1,
#   ID                                       Br[C@@]1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   SMILES_nostereo                              BrC1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1, dtype: object,
#   0),
#  (2,
#   ID                                       Br[C@@]1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   SMILES_nostereo                              BrC1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15F2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 2, dtype: object,
#   0),
#  (3,
#   ID                                       Br[C@@]1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   SMILES_nostereo                              BrC1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 3, dtype: object,
#   0),
#  (4,
#   ID                                       Br[C@@]1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   SMILES_nostereo                              BrC1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 4, dtype: object,
#   0),
#  (5,
#   ID                                       Br[C@@]1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   SMILES_nostereo                              BrC1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 5, dtype: object,
#   0),
#  (6,
#   ID                                       Br[C@@]1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   SMILES_nostereo                              BrC1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15F2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 6, dtype: object,
#   0),
#  (7,
#   ID                                       Br[C@@]1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   SMILES_nostereo                              BrC1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15F2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 7, dtype: object,
#   0),
#  (8,
#   ID                                        Br[C@]1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   SMILES_nostereo                              BrC1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15F2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 8, dtype: object,
#   0),
#  (9,
#   ID                                        Br[C@]1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   SMILES_nostereo                              BrC1(c2cccc(-c3ccccc3)c2)C=CC=CC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15F2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 9, dtype: object,
#   0),
#  (10,
#   ID                                           BrC[C@@H](Cc1ccc(Br)s1)c1ccccc1Br
#   SMILES_nostereo                                   BrCC(Cc1ccc(Br)s1)c1ccccc1Br
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15F2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 10, dtype: object,
#   0),
#  (11,
#   ID                                           BrC[C@@H](Cc1ccc(Br)s1)c1ccccc1Br
#   SMILES_nostereo                                   BrCC(Cc1ccc(Br)s1)c1ccccc1Br
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15F2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 11, dtype: object,
#   0),
#  (12,
#   ID                                           BrC[C@@H](Cc1ccc(Br)s1)c1ccccc1Br
#   SMILES_nostereo                                   BrCC(Cc1ccc(Br)s1)c1ccccc1Br
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15F2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 12, dtype: object,
#   0),
#  (13,
#   ID                                           BrC[C@@H](Cc1ccc(Br)s1)c1ccccc1Br
#   SMILES_nostereo                                   BrCC(Cc1ccc(Br)s1)c1ccccc1Br
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15F2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 13, dtype: object,
#   0),
#  (14,
#   ID                                            BrC[C@H](Cc1ccc(Br)s1)c1ccccc1Br
#   SMILES_nostereo                                   BrCC(Cc1ccc(Br)s1)c1ccccc1Br
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15F2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 14, dtype: object,
#   0),
#  (15,
#   ID                                            BrC[C@H](Cc1ccc(Br)s1)c1ccccc1Br
#   SMILES_nostereo                                   BrCC(Cc1ccc(Br)s1)c1ccccc1Br
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15F2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 15, dtype: object,
#   0),
#  (16,
#   ID                                            BrC[C@H](Cc1ccc(Br)s1)c1ccccc1Br
#   SMILES_nostereo                                   BrCC(Cc1ccc(Br)s1)c1ccccc1Br
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 16, dtype: object,
#   0),
#  (17,
#   ID                                            BrC[C@H](Cc1ccc(Br)s1)c1ccccc1Br
#   SMILES_nostereo                                   BrCC(Cc1ccc(Br)s1)c1ccccc1Br
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 17, dtype: object,
#   0),
#  (18,
#   ID                                            BrC[C@H](Cc1ccc(Br)s1)c1ccccc1Br
#   SMILES_nostereo                                   BrCC(Cc1ccc(Br)s1)c1ccccc1Br
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 18, dtype: object,
#   0),
#  (19,
#   ID                                            BrC[C@H](Cc1ccc(Br)s1)c1ccccc1Br
#   SMILES_nostereo                                   BrCC(Cc1ccc(Br)s1)c1ccccc1Br
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 19, dtype: object,
#   0),
#  (20,
#   ID                                                 Brc1ccc(CCN[C@@H]2CCCSC2)o1
#   SMILES_nostereo                                         Brc1ccc(CCNC2CCCSC2)o1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 20, dtype: object,
#   0),
#  (21,
#   ID                                                 Brc1ccc(CCN[C@@H]2CCCSC2)o1
#   SMILES_nostereo                                         Brc1ccc(CCNC2CCCSC2)o1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 21, dtype: object,
#   0),
#  (22,
#   ID                                                 Brc1ccc(CCN[C@@H]2CCCSC2)o1
#   SMILES_nostereo                                         Brc1ccc(CCNC2CCCSC2)o1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 22, dtype: object,
#   0),
#  (23,
#   ID                                                  Brc1ccc(CCN[C@H]2CCCSC2)o1
#   SMILES_nostereo                                         Brc1ccc(CCNC2CCCSC2)o1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23, dtype: object,
#   0),
#  (24,
#   ID                                                  Brc1ccc(CCN[C@H]2CCCSC2)o1
#   SMILES_nostereo                                         Brc1ccc(CCNC2CCCSC2)o1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 24, dtype: object,
#   0),
#  (25,
#   ID                                                  Brc1ccc(CCN[C@H]2CCCSC2)o1
#   SMILES_nostereo                                         Brc1ccc(CCNC2CCCSC2)o1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 25, dtype: object,
#   0),
#  (26,
#   ID                                                  Brc1ccc(CCN[C@H]2CCCSC2)o1
#   SMILES_nostereo                                         Brc1ccc(CCNC2CCCSC2)o1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 26, dtype: object,
#   0),
#  (27,
#   ID                                                  Brc1ccc(CCN[C@H]2CCCSC2)o1
#   SMILES_nostereo                                         Brc1ccc(CCNC2CCCSC2)o1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 27, dtype: object,
#   0),
#  (28,
#   ID                                                  Brc1ccc(CCN[C@H]2CCCSC2)o1
#   SMILES_nostereo                                         Brc1ccc(CCNC2CCCSC2)o1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 28, dtype: object,
#   0),
#  (29,
#   ID                                                  Brc1ccc(CCN[C@H]2CCCSC2)o1
#   SMILES_nostereo                                         Brc1ccc(CCNC2CCCSC2)o1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 29, dtype: object,
#   0),
#  (30,
#   ID                                    Brc1ccc2nc(CN3CC[C@@]4(CCOC4)C3)[nH]c2c1
#   SMILES_nostereo                           Brc1ccc2nc(CN3CCC4(CCOC4)C3)[nH]c2c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 30, dtype: object,
#   0),
#  (31,
#   ID                                    Brc1ccc2nc(CN3CC[C@@]4(CCOC4)C3)[nH]c2c1
#   SMILES_nostereo                           Brc1ccc2nc(CN3CCC4(CCOC4)C3)[nH]c2c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 31, dtype: object,
#   0),
#  (32,
#   ID                                    Brc1ccc2nc(CN3CC[C@@]4(CCOC4)C3)[nH]c2c1
#   SMILES_nostereo                           Brc1ccc2nc(CN3CCC4(CCOC4)C3)[nH]c2c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 32, dtype: object,
#   0),
#  (33,
#   ID                                    Brc1ccc2nc(CN3CC[C@@]4(CCOC4)C3)[nH]c2c1
#   SMILES_nostereo                           Brc1ccc2nc(CN3CCC4(CCOC4)C3)[nH]c2c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 33, dtype: object,
#   0),
#  (34,
#   ID                                    Brc1ccc2nc(CN3CC[C@@]4(CCOC4)C3)[nH]c2c1
#   SMILES_nostereo                           Brc1ccc2nc(CN3CCC4(CCOC4)C3)[nH]c2c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 34, dtype: object,
#   0),
#  (35,
#   ID                                     Brc1ccc2nc(CN3CC[C@]4(CCOC4)C3)[nH]c2c1
#   SMILES_nostereo                           Brc1ccc2nc(CN3CCC4(CCOC4)C3)[nH]c2c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 35, dtype: object,
#   0),
#  (36,
#   ID                                     Brc1ccc2nc(CN3CC[C@]4(CCOC4)C3)[nH]c2c1
#   SMILES_nostereo                           Brc1ccc2nc(CN3CCC4(CCOC4)C3)[nH]c2c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 36, dtype: object,
#   0),
#  (37,
#   ID                                     Brc1ccc2nc(CN3CC[C@]4(CCOC4)C3)[nH]c2c1
#   SMILES_nostereo                           Brc1ccc2nc(CN3CCC4(CCOC4)C3)[nH]c2c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 37, dtype: object,
#   0),
#  (38,
#   ID                                     Brc1ccc2nc(CN3CC[C@]4(CCOC4)C3)[nH]c2c1
#   SMILES_nostereo                           Brc1ccc2nc(CN3CCC4(CCOC4)C3)[nH]c2c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 38, dtype: object,
#   0),
#  (39,
#   ID                                     Brc1ccc2nc(CN3CC[C@]4(CCOC4)C3)[nH]c2c1
#   SMILES_nostereo                           Brc1ccc2nc(CN3CCC4(CCOC4)C3)[nH]c2c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 39, dtype: object,
#   0),
#  (40,
#   ID                                             Brc1cccc([C@@H]2Cc3ccccc3CO2)c1
#   SMILES_nostereo                                     Brc1cccc(C2Cc3ccccc3CO2)c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 40, dtype: object,
#   0),
#  (41,
#   ID                                             Brc1cccc([C@@H]2Cc3ccccc3CO2)c1
#   SMILES_nostereo                                     Brc1cccc(C2Cc3ccccc3CO2)c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 41, dtype: object,
#   0),
#  (42,
#   ID                                             Brc1cccc([C@@H]2Cc3ccccc3CO2)c1
#   SMILES_nostereo                                     Brc1cccc(C2Cc3ccccc3CO2)c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 42, dtype: object,
#   0),
#  (43,
#   ID                                             Brc1cccc([C@@H]2Cc3ccccc3CO2)c1
#   SMILES_nostereo                                     Brc1cccc(C2Cc3ccccc3CO2)c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 43, dtype: object,
#   0),
#  (44,
#   ID                                             Brc1cccc([C@@H]2Cc3ccccc3CO2)c1
#   SMILES_nostereo                                     Brc1cccc(C2Cc3ccccc3CO2)c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12F8...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 44, dtype: object,
#   0),
#  (45,
#   ID                                             Brc1cccc([C@@H]2Cc3ccccc3CO2)c1
#   SMILES_nostereo                                     Brc1cccc(C2Cc3ccccc3CO2)c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 45, dtype: object,
#   0),
#  (46,
#   ID                                              Brc1cccc([C@H]2Cc3ccccc3CO2)c1
#   SMILES_nostereo                                     Brc1cccc(C2Cc3ccccc3CO2)c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 46, dtype: object,
#   0),
#  (47,
#   ID                                              Brc1cccc([C@H]2Cc3ccccc3CO2)c1
#   SMILES_nostereo                                     Brc1cccc(C2Cc3ccccc3CO2)c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 47, dtype: object,
#   0),
#  (48,
#   ID                                              Brc1cccc([C@H]2Cc3ccccc3CO2)c1
#   SMILES_nostereo                                     Brc1cccc(C2Cc3ccccc3CO2)c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CB...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 48, dtype: object,
#   0),
#  (49,
#   ID                                              Brc1cccc([C@H]2Cc3ccccc3CO2)c1
#   SMILES_nostereo                                     Brc1cccc(C2Cc3ccccc3CO2)c1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CB...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 49, dtype: object,
#   0),
#  (50,
#   ID                                                     Brc1ccccc1[C@@H]1CNCCO1
#   SMILES_nostereo                                             Brc1ccccc1C1CNCCO1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 50, dtype: object,
#   0),
#  (51,
#   ID                                                     Brc1ccccc1[C@@H]1CNCCO1
#   SMILES_nostereo                                             Brc1ccccc1C1CNCCO1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 51, dtype: object,
#   0),
#  (52,
#   ID                                                     Brc1ccccc1[C@@H]1CNCCO1
#   SMILES_nostereo                                             Brc1ccccc1C1CNCCO1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 52, dtype: object,
#   0),
#  (53,
#   ID                                                     Brc1ccccc1[C@@H]1CNCCO1
#   SMILES_nostereo                                             Brc1ccccc1C1CNCCO1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 53, dtype: object,
#   0),
#  (54,
#   ID                                                      Brc1ccccc1[C@H]1CNCCO1
#   SMILES_nostereo                                             Brc1ccccc1C1CNCCO1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 54, dtype: object,
#   0),
#  (55,
#   ID                                                      Brc1ccccc1[C@H]1CNCCO1
#   SMILES_nostereo                                             Brc1ccccc1C1CNCCO1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CB...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 55, dtype: object,
#   0),
#  (56,
#   ID                                                      Brc1ccccc1[C@H]1CNCCO1
#   SMILES_nostereo                                             Brc1ccccc1C1CNCCO1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CB...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 56, dtype: object,
#   0),
#  (57,
#   ID                                                      Brc1ccccc1[C@H]1CNCCO1
#   SMILES_nostereo                                             Brc1ccccc1C1CNCCO1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CB...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 57, dtype: object,
#   0),
#  (58,
#   ID                                                      Brc1ccccc1[C@H]1CNCCO1
#   SMILES_nostereo                                             Brc1ccccc1C1CNCCO1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CB...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 58, dtype: object,
#   0),
#  (59,
#   ID                                                      Brc1ccccc1[C@H]1CNCCO1
#   SMILES_nostereo                                             Brc1ccccc1C1CNCCO1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CB...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 59, dtype: object,
#   0),
#  (60,
#   ID                                                     C#CC(=O)N[C@@]1(C)CCNC1
#   SMILES_nostereo                                            C#CC(=O)NC1(C)CCNC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CB...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 60, dtype: object,
#   0),
#  (61,
#   ID                                                     C#CC(=O)N[C@@]1(C)CCNC1
#   SMILES_nostereo                                            C#CC(=O)NC1(C)CCNC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CB...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 61, dtype: object,
#   0),
#  (62,
#   ID                                                     C#CC(=O)N[C@@]1(C)CCNC1
#   SMILES_nostereo                                            C#CC(=O)NC1(C)CCNC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CB...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 62, dtype: object,
#   0),
#  (63,
#   ID                                                      C#CC(=O)N[C@]1(C)CCNC1
#   SMILES_nostereo                                            C#CC(=O)NC1(C)CCNC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CB...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 63, dtype: object,
#   0),
#  (64,
#   ID                                                      C#CC(=O)N[C@]1(C)CCNC1
#   SMILES_nostereo                                            C#CC(=O)NC1(C)CCNC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CB...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 64, dtype: object,
#   0),
#  (65,
#   ID                                                      C#CC(=O)N[C@]1(C)CCNC1
#   SMILES_nostereo                                            C#CC(=O)NC1(C)CCNC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CC...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 65, dtype: object,
#   0),
#  (66,
#   ID                           C#C[C@@](C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C...
#   SMILES_nostereo              C#CC(C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C)c(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 66, dtype: object,
#   0),
#  (67,
#   ID                           C#C[C@@](C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C...
#   SMILES_nostereo              C#CC(C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C)c(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 67, dtype: object,
#   0),
#  (68,
#   ID                           C#C[C@@](C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C...
#   SMILES_nostereo              C#CC(C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C)c(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 68, dtype: object,
#   0),
#  (69,
#   ID                           C#C[C@@](C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C...
#   SMILES_nostereo              C#CC(C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C)c(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 69, dtype: object,
#   0),
#  (70,
#   ID                           C#C[C@@](C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C...
#   SMILES_nostereo              C#CC(C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C)c(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 70, dtype: object,
#   0),
#  (71,
#   ID                           C#C[C@@](C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C...
#   SMILES_nostereo              C#CC(C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C)c(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 71, dtype: object,
#   0),
#  (72,
#   ID                           C#C[C@@](C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C...
#   SMILES_nostereo              C#CC(C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C)c(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 72, dtype: object,
#   0),
#  (73,
#   ID                           C#C[C@](C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C)...
#   SMILES_nostereo              C#CC(C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C)c(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 73, dtype: object,
#   0),
#  (74,
#   ID                           C#C[C@](C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C)...
#   SMILES_nostereo              C#CC(C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C)c(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 74, dtype: object,
#   0),
#  (75,
#   ID                           C#C[C@](C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C)...
#   SMILES_nostereo              C#CC(C)(COP(=O)([O-])[O-])NC(=O)C(=O)c1c(C)c(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 75, dtype: object,
#   0),
#  (76,
#   ID                                                    C#C[C@@H](CCCCC)C1CCCCC1
#   SMILES_nostereo                                            C#CC(CCCCC)C1CCCCC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 76, dtype: object,
#   0),
#  (77,
#   ID                                                    C#C[C@@H](CCCCC)C1CCCCC1
#   SMILES_nostereo                                            C#CC(CCCCC)C1CCCCC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 77, dtype: object,
#   0),
#  (78,
#   ID                                                    C#C[C@@H](CCCCC)C1CCCCC1
#   SMILES_nostereo                                            C#CC(CCCCC)C1CCCCC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 78, dtype: object,
#   0),
#  (79,
#   ID                                                    C#C[C@@H](CCCCC)C1CCCCC1
#   SMILES_nostereo                                            C#CC(CCCCC)C1CCCCC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 79, dtype: object,
#   0),
#  (80,
#   ID                                                     C#C[C@H](CCCCC)C1CCCCC1
#   SMILES_nostereo                                            C#CC(CCCCC)C1CCCCC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CC...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 80, dtype: object,
#   0),
#  (81,
#   ID                                                     C#C[C@H](CCCCC)C1CCCCC1
#   SMILES_nostereo                                            C#CC(CCCCC)C1CCCCC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CC...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 81, dtype: object,
#   0),
#  (82,
#   ID                                                     C#C[C@H](CCCCC)C1CCCCC1
#   SMILES_nostereo                                            C#CC(CCCCC)C1CCCCC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CC...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 82, dtype: object,
#   0),
#  (83,
#   ID                                                     C#C[C@H](CCCCC)C1CCCCC1
#   SMILES_nostereo                                            C#CC(CCCCC)C1CCCCC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CC...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 83, dtype: object,
#   0),
#  (84,
#   ID                                                     C#C[C@H](CCCCC)C1CCCCC1
#   SMILES_nostereo                                            C#CC(CCCCC)C1CCCCC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CC...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 84, dtype: object,
#   0),
#  (85,
#   ID                                                     C#C[C@H](CCCCC)C1CCCCC1
#   SMILES_nostereo                                            C#CC(CCCCC)C1CCCCC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CC...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 85, dtype: object,
#   0),
#  (86,
#   ID                                     C#C[C@@H](COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   SMILES_nostereo                             C#CC(COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13CC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 86, dtype: object,
#   0),
#  (87,
#   ID                                     C#C[C@@H](COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   SMILES_nostereo                             C#CC(COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 87, dtype: object,
#   0),
#  (88,
#   ID                                     C#C[C@@H](COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   SMILES_nostereo                             C#CC(COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 88, dtype: object,
#   0),
#  (89,
#   ID                                      C#C[C@H](COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   SMILES_nostereo                             C#CC(COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 89, dtype: object,
#   0),
#  (90,
#   ID                                      C#C[C@H](COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   SMILES_nostereo                             C#CC(COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 90, dtype: object,
#   0),
#  (91,
#   ID                                      C#C[C@H](COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   SMILES_nostereo                             C#CC(COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 91, dtype: object,
#   0),
#  (92,
#   ID                                      C#C[C@H](COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   SMILES_nostereo                             C#CC(COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 92, dtype: object,
#   0),
#  (93,
#   ID                                      C#C[C@H](COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   SMILES_nostereo                             C#CC(COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 93, dtype: object,
#   0),
#  (94,
#   ID                                      C#C[C@H](COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   SMILES_nostereo                             C#CC(COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 94, dtype: object,
#   0),
#  (95,
#   ID                                      C#C[C@H](COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   SMILES_nostereo                             C#CC(COC)NC(=O)c1cnn2c(C)cc(C)nc12
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 95, dtype: object,
#   0),
#  (96,
#   ID                                                    C#CC[C@@](C)(CN)c1ccccc1
#   SMILES_nostereo                                           C#CCC(C)(CN)c1ccccc1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 96, dtype: object,
#   0),
#  (97,
#   ID                                                    C#CC[C@@](C)(CN)c1ccccc1
#   SMILES_nostereo                                           C#CCC(C)(CN)c1ccccc1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 97, dtype: object,
#   0),
#  (98,
#   ID                                                    C#CC[C@@](C)(CN)c1ccccc1
#   SMILES_nostereo                                           C#CCC(C)(CN)c1ccccc1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 98, dtype: object,
#   0),
#  (99,
#   ID                                                    C#CC[C@@](C)(CN)c1ccccc1
#   SMILES_nostereo                                           C#CCC(C)(CN)c1ccccc1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 99, dtype: object,
#   0),
#  (100,
#   ID                                                    C#CC[C@@](C)(CN)c1ccccc1
#   SMILES_nostereo                                           C#CCC(C)(CN)c1ccccc1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 100, dtype: object,
#   0),
#  (101,
#   ID                                                    C#CC[C@@](C)(CN)c1ccccc1
#   SMILES_nostereo                                           C#CCC(C)(CN)c1ccccc1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 101, dtype: object,
#   0),
#  (102,
#   ID                                                     C#CC[C@](C)(CN)c1ccccc1
#   SMILES_nostereo                                           C#CCC(C)(CN)c1ccccc1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 102, dtype: object,
#   0),
#  (103,
#   ID                                                     C#CC[C@](C)(CN)c1ccccc1
#   SMILES_nostereo                                           C#CCC(C)(CN)c1ccccc1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 103, dtype: object,
#   0),
#  (104,
#   ID                                                     C#CC[C@](C)(CN)c1ccccc1
#   SMILES_nostereo                                           C#CCC(C)(CN)c1ccccc1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 104, dtype: object,
#   0),
#  (105,
#   ID                                                     C#CC[C@](C)(CN)c1ccccc1
#   SMILES_nostereo                                           C#CCC(C)(CN)c1ccccc1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 105, dtype: object,
#   0),
#  (106,
#   ID                                        C#CC[C@@H](CC)NC(=O)N(CC(=O)O)CC(C)C
#   SMILES_nostereo                                C#CCC(CC)NC(=O)N(CC(=O)O)CC(C)C
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 106, dtype: object,
#   0),
#  (107,
#   ID                                        C#CC[C@@H](CC)NC(=O)N(CC(=O)O)CC(C)C
#   SMILES_nostereo                                C#CCC(CC)NC(=O)N(CC(=O)O)CC(C)C
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 107, dtype: object,
#   0),
#  (108,
# ...
#   SMILES_nostereo                                       C=C(C)CN(CC)C(=O)CCC(C)N
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13AB...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 964, dtype: object,
#   0),
#  (965,
#   ID                                               C=C(C)CN(CC)C(=O)CC[C@@H](C)N
#   SMILES_nostereo                                       C=C(C)CN(CC)C(=O)CCC(C)N
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13AB...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 965, dtype: object,
#   0),
#  (966,
#   ID                                               C=C(C)CN(CC)C(=O)CC[C@@H](C)N
#   SMILES_nostereo                                       C=C(C)CN(CC)C(=O)CCC(C)N
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13AB...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 966, dtype: object,
#   0),
#  (967,
#   ID                                               C=C(C)CN(CC)C(=O)CC[C@@H](C)N
#   SMILES_nostereo                                       C=C(C)CN(CC)C(=O)CCC(C)N
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13AB...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 967, dtype: object,
#   0),
#  (968,
#   ID                                               C=C(C)CN(CC)C(=O)CC[C@@H](C)N
#   SMILES_nostereo                                       C=C(C)CN(CC)C(=O)CCC(C)N
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13AB...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 968, dtype: object,
#   0),
#  (969,
#   ID                                               C=C(C)CN(CC)C(=O)CC[C@@H](C)N
#   SMILES_nostereo                                       C=C(C)CN(CC)C(=O)CCC(C)N
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13AB...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 969, dtype: object,
#   0),
#  (970,
#   ID                                               C=C(C)CN(CC)C(=O)CC[C@@H](C)N
#   SMILES_nostereo                                       C=C(C)CN(CC)C(=O)CCC(C)N
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13AB...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 970, dtype: object,
#   0),
#  (971,
#   ID                                                C=C(C)CN(CC)C(=O)CC[C@H](C)N
#   SMILES_nostereo                                       C=C(C)CN(CC)C(=O)CCC(C)N
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13AB...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 971, dtype: object,
#   0),
#  (972,
#   ID                                                C=C(C)CN(CC)C(=O)CC[C@H](C)N
#   SMILES_nostereo                                       C=C(C)CN(CC)C(=O)CCC(C)N
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13AB...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 972, dtype: object,
#   0),
#  (973,
#   ID                                              C=C(C)CN1CCO[C@@H](Cn2cncn2)C1
#   SMILES_nostereo                                      C=C(C)CN1CCOC(Cn2cncn2)C1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13AB...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 973, dtype: object,
#   0),
#  (974,
#   ID                                              C=C(C)CN1CCO[C@@H](Cn2cncn2)C1
#   SMILES_nostereo                                      C=C(C)CN1CCOC(Cn2cncn2)C1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13AB...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 974, dtype: object,
#   0),
#  (975,
#   ID                                              C=C(C)CN1CCO[C@@H](Cn2cncn2)C1
#   SMILES_nostereo                                      C=C(C)CN1CCOC(Cn2cncn2)C1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13AB...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 975, dtype: object,
#   0),
#  (976,
#   ID                                              C=C(C)CN1CCO[C@@H](Cn2cncn2)C1
#   SMILES_nostereo                                      C=C(C)CN1CCOC(Cn2cncn2)C1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13AB...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 976, dtype: object,
#   0),
#  (977,
#   ID                                              C=C(C)CN1CCO[C@@H](Cn2cncn2)C1
#   SMILES_nostereo                                      C=C(C)CN1CCOC(Cn2cncn2)C1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13AB...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 977, dtype: object,
#   0),
#  (978,
#   ID                                               C=C(C)CN1CCO[C@H](Cn2cncn2)C1
#   SMILES_nostereo                                      C=C(C)CN1CCOC(Cn2cncn2)C1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13FC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 978, dtype: object,
#   0),
#  (979,
#   ID                                               C=C(C)CN1CCO[C@H](Cn2cncn2)C1
#   SMILES_nostereo                                      C=C(C)CN1CCOC(Cn2cncn2)C1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1308...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 979, dtype: object,
#   0),
#  (980,
#   ID                                               C=C(C)CN1CCO[C@H](Cn2cncn2)C1
#   SMILES_nostereo                                      C=C(C)CN1CCOC(Cn2cncn2)C1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C138A...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 980, dtype: object,
#   0),
#  (981,
#   ID                                               C=C(C)CN1CCO[C@H](Cn2cncn2)C1
#   SMILES_nostereo                                      C=C(C)CN1CCOC(Cn2cncn2)C1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145D...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 981, dtype: object,
#   0),
#  (982,
#   ID                                               C=C(C)CN1CCO[C@H](Cn2cncn2)C1
#   SMILES_nostereo                                      C=C(C)CN1CCOC(Cn2cncn2)C1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15E2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 982, dtype: object,
#   0),
#  (983,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 983, dtype: object,
#   0),
#  (984,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 984, dtype: object,
#   0),
#  (985,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 985, dtype: object,
#   0),
#  (986,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 986, dtype: object,
#   0),
#  (987,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 987, dtype: object,
#   0),
#  (988,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1521...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 988, dtype: object,
#   0),
#  (989,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 989, dtype: object,
#   0),
#  (990,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135A...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 990, dtype: object,
#   0),
#  (991,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12AF...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 991, dtype: object,
#   0),
#  (992,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12AF...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 992, dtype: object,
#   0),
#  (993,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 993, dtype: object,
#   0),
#  (994,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145E...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 994, dtype: object,
#   0),
#  (995,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 995, dtype: object,
#   0),
#  (996,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 996, dtype: object,
#   0),
#  (997,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145E...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 997, dtype: object,
#   0),
#  (998,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145E...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 998, dtype: object,
#   0),
#  (999,
#   ID                                            C=C(C)COCCNC(=O)N[C@@H](C)C(=O)O
#   SMILES_nostereo                                    C=C(C)COCCNC(=O)NC(C)C(=O)O
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1613...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 999, dtype: object,
#   0),
#  ...]

# %% [markdown]
# ## Filter according to returned value, need exactly one and build new dataframe

# %%
filtered_list = list(filter(
    lambda x: x[2] == 1,
    df_collection
))

# %%
len(filtered_list)
# Out:
# 3970

# %%
filtered_list = sorted(filtered_list, key=lambda x: x[0])

# %%
filtered_list
# Out:
# [(506,
#   ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15E2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 506, dtype: object,
#   1),
#  (507,
#   ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C138A...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 507, dtype: object,
#   1),
#  (508,
#   ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15E2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 508, dtype: object,
#   1),
#  (509,
#   ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13FC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 509, dtype: object,
#   1),
#  (510,
#   ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13FC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 510, dtype: object,
#   1),
#  (511,
#   ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 511, dtype: object,
#   1),
#  (512,
#   ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15E2...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 512, dtype: object,
#   1),
#  (513,
#   ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 513, dtype: object,
#   1),
#  (514,
#   ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C138A...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 514, dtype: object,
#   1),
#  (515,
#   ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13FC...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 515, dtype: object,
#   1),
#  (516,
#   ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C138A...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 516, dtype: object,
#   1),
#  (517,
#   ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15E2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 517, dtype: object,
#   1),
#  (518,
#   ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13FC...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 518, dtype: object,
#   1),
#  (519,
#   ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15E2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 519, dtype: object,
#   1),
#  (520,
#   ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 520, dtype: object,
#   1),
#  (521,
#   ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C149E...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 521, dtype: object,
#   1),
#  (522,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1349...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 522, dtype: object,
#   1),
#  (523,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1349...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 523, dtype: object,
#   1),
#  (524,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 524, dtype: object,
#   1),
#  (525,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1349...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 525, dtype: object,
#   1),
#  (526,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 526, dtype: object,
#   1),
#  (527,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C149E...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 527, dtype: object,
#   1),
#  (528,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 528, dtype: object,
#   1),
#  (529,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1349...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 529, dtype: object,
#   1),
#  (530,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 530, dtype: object,
#   1),
#  (531,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1521...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 531, dtype: object,
#   1),
#  (532,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 532, dtype: object,
#   1),
#  (533,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1521...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 533, dtype: object,
#   1),
#  (534,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135A...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 534, dtype: object,
#   1),
#  (535,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1520...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 535, dtype: object,
#   1),
#  (536,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135A...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 536, dtype: object,
#   1),
#  (537,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 537, dtype: object,
#   1),
#  (538,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 538, dtype: object,
#   1),
#  (539,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 539, dtype: object,
#   1),
#  (540,
#   ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#   SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 540, dtype: object,
#   1),
#  (541,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135A...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 541, dtype: object,
#   1),
#  (542,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135A...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 542, dtype: object,
#   1),
#  (543,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1520...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 543, dtype: object,
#   1),
#  (544,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135A...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 544, dtype: object,
#   1),
#  (545,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1521...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 545, dtype: object,
#   1),
#  (546,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 546, dtype: object,
#   1),
#  (547,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 547, dtype: object,
#   1),
#  (548,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 548, dtype: object,
#   1),
#  (549,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 549, dtype: object,
#   1),
#  (550,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 550, dtype: object,
#   1),
#  (551,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 551, dtype: object,
#   1),
#  (552,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 552, dtype: object,
#   1),
#  (553,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 553, dtype: object,
#   1),
#  (554,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 554, dtype: object,
#   1),
#  (555,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 555, dtype: object,
#   1),
#  (556,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 556, dtype: object,
#   1),
#  (557,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 557, dtype: object,
#   1),
#  (558,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 558, dtype: object,
#   1),
#  (559,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 559, dtype: object,
#   1),
#  (560,
#   ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#   SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 560, dtype: object,
#   1),
#  (597,
#   ID                           C1=CC=C([C@@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c...
#   SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 597, dtype: object,
#   1),
#  (598,
#   ID                           C1=CC=C([C@@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c...
#   SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12AF...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 598, dtype: object,
#   1),
#  (599,
#   ID                           C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#   SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145E...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 599, dtype: object,
#   1),
#  (600,
#   ID                           C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#   SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145E...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 600, dtype: object,
#   1),
#  (601,
#   ID                           C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#   SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 601, dtype: object,
#   1),
#  (602,
#   ID                           C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#   SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 602, dtype: object,
#   1),
#  (603,
#   ID                           C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#   SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 603, dtype: object,
#   1),
#  (604,
#   ID                           C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#   SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 604, dtype: object,
#   1),
#  (605,
#   ID                           C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#   SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 605, dtype: object,
#   1),
#  (606,
#   ID                           C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#   SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 606, dtype: object,
#   1),
#  (814,
#   ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#   SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 814, dtype: object,
#   1),
#  (815,
#   ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#   SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 815, dtype: object,
#   1),
#  (816,
#   ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#   SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 816, dtype: object,
#   1),
#  (817,
#   ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#   SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 817, dtype: object,
#   1),
#  (818,
#   ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#   SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 818, dtype: object,
#   1),
#  (819,
#   ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#   SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 819, dtype: object,
#   1),
#  (820,
#   ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#   SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 820, dtype: object,
#   1),
#  (821,
#   ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#   SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 821, dtype: object,
#   1),
#  (822,
#   ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#   SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 822, dtype: object,
#   1),
#  (823,
#   ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#   SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 823, dtype: object,
#   1),
#  (1013,
#   ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@@H](C...
#   SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135B...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 1013, dtype: object,
#   1),
#  (1014,
#   ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@@H](C...
#   SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12C8...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 1014, dtype: object,
#   1),
#  (1015,
#   ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@@H](C...
#   SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135B...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 1015, dtype: object,
#   1),
#  (1016,
#   ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#   SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12C8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1016, dtype: object,
#   1),
#  (1017,
#   ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#   SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12C8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1017, dtype: object,
#   1),
#  (1018,
#   ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#   SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12C8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1018, dtype: object,
#   1),
#  (1019,
#   ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#   SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12C8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1019, dtype: object,
#   1),
#  (1020,
#   ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#   SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135B...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1020, dtype: object,
#   1),
#  (1021,
#   ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#   SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12C8...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1021, dtype: object,
#   1),
#  (1022,
#   ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#   SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135B...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1022, dtype: object,
#   1),
#  (1023,
#   ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@@H]...
#   SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C140C...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 1023, dtype: object,
#   1),
#  (1024,
#   ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@@H]...
#   SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C140C...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 1024, dtype: object,
#   1),
#  (1025,
#   ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@@H]...
#   SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 1025, dtype: object,
#   1),
#  (1026,
#   ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@@H]...
#   SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C140C...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 1026, dtype: object,
#   1),
#  (1027,
#   ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@@H]...
#   SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C140C...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 1027, dtype: object,
#   1),
#  (1028,
#   ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@@H]...
#   SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C140C...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 1028, dtype: object,
#   1),
#  (1029,
#   ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@H](...
#   SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1339...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1029, dtype: object,
#   1),
#  (1030,
#   ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@H](...
#   SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1030, dtype: object,
#   1),
#  (1031,
#   ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@H](...
#   SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1031, dtype: object,
#   1),
#  (1032,
#   ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@H](...
#   SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1032, dtype: object,
#   1),
#  (1213,
#   ID                                                  C=C/C(=C\N[C@@](F)(P)CO)OC
#   SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 1213, dtype: object,
#   1),
#  (1214,
#   ID                                                  C=C/C(=C\N[C@@](F)(P)CO)OC
#   SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 1214, dtype: object,
#   1),
#  (1215,
#   ID                                                  C=C/C(=C\N[C@@](F)(P)CO)OC
#   SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 1215, dtype: object,
#   1),
#  (1216,
#   ID                                                   C=C/C(=C\N[C@](F)(P)CO)OC
#   SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1216, dtype: object,
#   1),
#  (1217,
#   ID                                                   C=C/C(=C\N[C@](F)(P)CO)OC
#   SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1217, dtype: object,
#   1),
#  (1218,
#   ID                                                   C=C/C(=C\N[C@](F)(P)CO)OC
#   SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1218, dtype: object,
#   1),
#  (1219,
#   ID                                                   C=C/C(=C\N[C@](F)(P)CO)OC
#   SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1219, dtype: object,
#   1),
#  (1220,
#   ID                                                   C=C/C(=C\N[C@](F)(P)CO)OC
#   SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1220, dtype: object,
#   1),
#  (1221,
#   ID                                                   C=C/C(=C\N[C@](F)(P)CO)OC
#   SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1221, dtype: object,
#   1),
#  (1222,
#   ID                                                   C=C/C(=C\N[C@](F)(P)CO)OC
#   SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 1222, dtype: object,
#   1),
#  (1283,
#   ID                                                     C=C[C@@](C)(C#N)C/C=C/C
#   SMILES_nostereo                                              C=CC(C)(C#N)CC=CC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13BB...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 1283, dtype: object,
#   1),
#  (1284,
#   ID                                                     C=C[C@@](C)(C#N)C/C=C/C
#   SMILES_nostereo                                              C=CC(C)(C#N)CC=CC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13BB...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 1284, dtype: object,
#   1),
#  (1285,
#   ID                                                     C=C[C@@](C)(C#N)C/C=C/C
#   SMILES_nostereo                                              C=CC(C)(C#N)CC=CC
# ...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23432, dtype: object,
#   1),
#  (23433,
#   ID                                   CCCCCCCCC(=O)O/C1=C/[C@H](C)CCCCCCCCCCCC1
#   SMILES_nostereo                            CCCCCCCCC(=O)OC1=CC(C)CCCCCCCCCCCC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23433, dtype: object,
#   1),
#  (23434,
#   ID                                   CCCCCCCCC(=O)O/C1=C/[C@H](C)CCCCCCCCCCCC1
#   SMILES_nostereo                            CCCCCCCCC(=O)OC1=CC(C)CCCCCCCCCCCC1
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23434, dtype: object,
#   1),
#  (23525,
#   ID                                           CCCCCCCC/C=C/CCCCCC[C@@H](C)C(C)C
#   SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1752...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23525, dtype: object,
#   1),
#  (23526,
#   ID                                           CCCCCCCC/C=C/CCCCCC[C@@H](C)C(C)C
#   SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1752...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23526, dtype: object,
#   1),
#  (23527,
#   ID                                           CCCCCCCC/C=C/CCCCCC[C@@H](C)C(C)C
#   SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1752...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23527, dtype: object,
#   1),
#  (23528,
#   ID                                           CCCCCCCC/C=C/CCCCCC[C@@H](C)C(C)C
#   SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23528, dtype: object,
#   1),
#  (23529,
#   ID                                           CCCCCCCC/C=C/CCCCCC[C@@H](C)C(C)C
#   SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1752...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23529, dtype: object,
#   1),
#  (23530,
#   ID                                           CCCCCCCC/C=C/CCCCCC[C@@H](C)C(C)C
#   SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23530, dtype: object,
#   1),
#  (23531,
#   ID                                            CCCCCCCC/C=C/CCCCCC[C@H](C)C(C)C
#   SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23531, dtype: object,
#   1),
#  (23532,
#   ID                                            CCCCCCCC/C=C/CCCCCC[C@H](C)C(C)C
#   SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23532, dtype: object,
#   1),
#  (23533,
#   ID                                            CCCCCCCC/C=C/CCCCCC[C@H](C)C(C)C
#   SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23533, dtype: object,
#   1),
#  (23534,
#   ID                                            CCCCCCCC/C=C/CCCCCC[C@H](C)C(C)C
#   SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23534, dtype: object,
#   1),
#  (23575,
#   ID                                               CCCCCCCCCC[C@@H](C/C=C/C=O)OC
#   SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23575, dtype: object,
#   1),
#  (23576,
#   ID                                               CCCCCCCCCC[C@@H](C/C=C/C=O)OC
#   SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23576, dtype: object,
#   1),
#  (23577,
#   ID                                               CCCCCCCCCC[C@@H](C/C=C/C=O)OC
#   SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23577, dtype: object,
#   1),
#  (23578,
#   ID                                               CCCCCCCCCC[C@@H](C/C=C/C=O)OC
#   SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23578, dtype: object,
#   1),
#  (23579,
#   ID                                               CCCCCCCCCC[C@@H](C/C=C/C=O)OC
#   SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23579, dtype: object,
#   1),
#  (23580,
#   ID                                               CCCCCCCCCC[C@@H](C/C=C/C=O)OC
#   SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23580, dtype: object,
#   1),
#  (23581,
#   ID                                               CCCCCCCCCC[C@@H](C/C=C/C=O)OC
#   SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23581, dtype: object,
#   1),
#  (23582,
#   ID                                                CCCCCCCCCC[C@H](C/C=C/C=O)OC
#   SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23582, dtype: object,
#   1),
#  (23583,
#   ID                                                CCCCCCCCCC[C@H](C/C=C/C=O)OC
#   SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23583, dtype: object,
#   1),
#  (23584,
#   ID                                                CCCCCCCCCC[C@H](C/C=C/C=O)OC
#   SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23584, dtype: object,
#   1),
#  (23635,
#   ID                           CCCCCCCCN(CC[C@@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N...
#   SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23635, dtype: object,
#   1),
#  (23636,
#   ID                           CCCCCCCCN(CC[C@@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N...
#   SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23636, dtype: object,
#   1),
#  (23637,
#   ID                           CCCCCCCCN(CC[C@@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N...
#   SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23637, dtype: object,
#   1),
#  (23638,
#   ID                           CCCCCCCCN(CC[C@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N/...
#   SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23638, dtype: object,
#   1),
#  (23639,
#   ID                           CCCCCCCCN(CC[C@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N/...
#   SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23639, dtype: object,
#   1),
#  (23640,
#   ID                           CCCCCCCCN(CC[C@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N/...
#   SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23640, dtype: object,
#   1),
#  (23641,
#   ID                           CCCCCCCCN(CC[C@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N/...
#   SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23641, dtype: object,
#   1),
#  (23642,
#   ID                           CCCCCCCCN(CC[C@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N/...
#   SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23642, dtype: object,
#   1),
#  (23643,
#   ID                           CCCCCCCCN(CC[C@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N/...
#   SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23643, dtype: object,
#   1),
#  (23644,
#   ID                           CCCCCCCCN(CC[C@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N/...
#   SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#   RS_label                                                                     S
#   RS_label_binary                                                              1
#   Name: 23644, dtype: object,
#   1),
#  (23855,
#   ID                           CCCCCOc1ccc([C@@H]2/C(=C(\O)c3ccc4c(c3)OCCO4)C...
#   SMILES_nostereo              CCCCCOc1ccc(C2C(=C(O)c3ccc4c(c3)OCCO4)C(=O)C(=...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23855, dtype: object,
#   1),
#  (23856,
#   ID                           CCCCCOc1ccc([C@@H]2/C(=C(\O)c3ccc4c(c3)OCCO4)C...
#   SMILES_nostereo              CCCCCOc1ccc(C2C(=C(O)c3ccc4c(c3)OCCO4)C(=O)C(=...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1755...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23856, dtype: object,
#   1),
#  (23857,
#   ID                           CCCCCOc1ccc([C@@H]2/C(=C(\O)c3ccc4c(c3)OCCO4)C...
#   SMILES_nostereo              CCCCCOc1ccc(C2C(=C(O)c3ccc4c(c3)OCCO4)C(=O)C(=...
#   rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1755...
#   RS_label                                                                     R
#   RS_label_binary                                                              0
#   Name: 23857, dtype: object,
#   1),
#  ...]

# %%
# remove first and last element from tuples
filtered_list = [
    elem[1]
    for elem in filtered_list
]

# %%
filtered_list
# Out:
# [ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15E2...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 506, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C138A...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 507, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15E2...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 508, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13FC...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 509, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13FC...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 510, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 511, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15E2...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 512, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 513, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C138A...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 514, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13FC...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 515, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C138A...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 516, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15E2...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 517, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13FC...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 518, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C15E2...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 519, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 520, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C149E...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 521, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1349...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 522, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1349...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 523, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 524, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1349...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 525, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 526, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C149E...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 527, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 528, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1349...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 529, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 530, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1521...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 531, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 532, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1521...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 533, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135A...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 534, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1520...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 535, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135A...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 536, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 537, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 538, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 539, dtype: object,
#  ID                           C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#  SMILES_nostereo              C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 540, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135A...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 541, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135A...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 542, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1520...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 543, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135A...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 544, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1521...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 545, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 546, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 547, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 548, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 549, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 550, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 551, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 552, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 553, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 554, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 555, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 556, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 557, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 558, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1329...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 559, dtype: object,
#  ID                           C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#  SMILES_nostereo              C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13DC...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 560, dtype: object,
#  ID                           C1=CC=C([C@@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c...
#  SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 597, dtype: object,
#  ID                           C1=CC=C([C@@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c...
#  SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12AF...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 598, dtype: object,
#  ID                           C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#  SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145E...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 599, dtype: object,
#  ID                           C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#  SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C145E...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 600, dtype: object,
#  ID                           C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#  SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 601, dtype: object,
#  ID                           C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#  SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 602, dtype: object,
#  ID                           C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#  SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 603, dtype: object,
#  ID                           C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#  SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 604, dtype: object,
#  ID                           C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#  SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 605, dtype: object,
#  ID                           C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#  SMILES_nostereo              C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B0...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 606, dtype: object,
#  ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 814, dtype: object,
#  ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 815, dtype: object,
#  ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 816, dtype: object,
#  ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 817, dtype: object,
#  ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 818, dtype: object,
#  ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 819, dtype: object,
#  ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 820, dtype: object,
#  ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 821, dtype: object,
#  ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 822, dtype: object,
#  ID                           C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo              C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 823, dtype: object,
#  ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@@H](C...
#  SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135B...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1013, dtype: object,
#  ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@@H](C...
#  SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12C8...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1014, dtype: object,
#  ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@@H](C...
#  SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135B...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1015, dtype: object,
#  ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#  SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12C8...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1016, dtype: object,
#  ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#  SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12C8...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1017, dtype: object,
#  ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#  SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12C8...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1018, dtype: object,
#  ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#  SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12C8...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1019, dtype: object,
#  ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#  SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135B...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1020, dtype: object,
#  ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#  SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12C8...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1021, dtype: object,
#  ID                           C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#  SMILES_nostereo              C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C135B...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1022, dtype: object,
#  ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@@H]...
#  SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C140C...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1023, dtype: object,
#  ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@@H]...
#  SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C140C...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1024, dtype: object,
#  ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@@H]...
#  SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B7...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1025, dtype: object,
#  ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@@H]...
#  SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C140C...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1026, dtype: object,
#  ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@@H]...
#  SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C140C...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1027, dtype: object,
#  ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@@H]...
#  SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C140C...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1028, dtype: object,
#  ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@H](...
#  SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1339...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1029, dtype: object,
#  ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@H](...
#  SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1030, dtype: object,
#  ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@H](...
#  SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1031, dtype: object,
#  ID                           C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@H](...
#  SMILES_nostereo                   C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C12B2...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1032, dtype: object,
#  ID                                                  C=C/C(=C\N[C@@](F)(P)CO)OC
#  SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1213, dtype: object,
#  ID                                                  C=C/C(=C\N[C@@](F)(P)CO)OC
#  SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1214, dtype: object,
#  ID                                                  C=C/C(=C\N[C@@](F)(P)CO)OC
#  SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1215, dtype: object,
#  ID                                                   C=C/C(=C\N[C@](F)(P)CO)OC
#  SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1216, dtype: object,
#  ID                                                   C=C/C(=C\N[C@](F)(P)CO)OC
#  SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1217, dtype: object,
#  ID                                                   C=C/C(=C\N[C@](F)(P)CO)OC
#  SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1218, dtype: object,
#  ID                                                   C=C/C(=C\N[C@](F)(P)CO)OC
#  SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1219, dtype: object,
#  ID                                                   C=C/C(=C\N[C@](F)(P)CO)OC
#  SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1220, dtype: object,
#  ID                                                   C=C/C(=C\N[C@](F)(P)CO)OC
#  SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1221, dtype: object,
#  ID                                                   C=C/C(=C\N[C@](F)(P)CO)OC
#  SMILES_nostereo                                           C=CC(=CNC(F)(P)CO)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C139B...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1222, dtype: object,
#  ID                                                     C=C[C@@](C)(C#N)C/C=C/C
#  SMILES_nostereo                                              C=CC(C)(C#N)CC=CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13BB...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1283, dtype: object,
#  ID                                                     C=C[C@@](C)(C#N)C/C=C/C
#  SMILES_nostereo                                              C=CC(C)(C#N)CC=CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13BB...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1284, dtype: object,
#  ID                                                     C=C[C@@](C)(C#N)C/C=C/C
#  SMILES_nostereo                                              C=CC(C)(C#N)CC=CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13BB...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1285, dtype: object,
#  ID                                                     C=C[C@@](C)(C#N)C/C=C/C
#  SMILES_nostereo                                              C=CC(C)(C#N)CC=CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13BB...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1286, dtype: object,
#  ID                                                     C=C[C@@](C)(C#N)C/C=C/C
#  SMILES_nostereo                                              C=CC(C)(C#N)CC=CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13BB...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 1287, dtype: object,
#  ID                                                      C=C[C@](C)(C#N)C/C=C/C
#  SMILES_nostereo                                              C=CC(C)(C#N)CC=CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13BB...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1288, dtype: object,
#  ID                                                      C=C[C@](C)(C#N)C/C=C/C
#  SMILES_nostereo                                              C=CC(C)(C#N)CC=CC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C13BB...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 1289, dtype: object,
#  ID                                                      C=C[C@](C)(C#N)C/C=C/C
# ...
#  RS_label_binary                                                              0
#  Name: 23430, dtype: object,
#  ID                                   CCCCCCCCC(=O)O/C1=C/[C@H](C)CCCCCCCCCCCC1
#  SMILES_nostereo                            CCCCCCCCC(=O)OC1=CC(C)CCCCCCCCCCCC1
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23431, dtype: object,
#  ID                                   CCCCCCCCC(=O)O/C1=C/[C@H](C)CCCCCCCCCCCC1
#  SMILES_nostereo                            CCCCCCCCC(=O)OC1=CC(C)CCCCCCCCCCCC1
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23432, dtype: object,
#  ID                                   CCCCCCCCC(=O)O/C1=C/[C@H](C)CCCCCCCCCCCC1
#  SMILES_nostereo                            CCCCCCCCC(=O)OC1=CC(C)CCCCCCCCCCCC1
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23433, dtype: object,
#  ID                                   CCCCCCCCC(=O)O/C1=C/[C@H](C)CCCCCCCCCCCC1
#  SMILES_nostereo                            CCCCCCCCC(=O)OC1=CC(C)CCCCCCCCCCCC1
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23434, dtype: object,
#  ID                                           CCCCCCCC/C=C/CCCCCC[C@@H](C)C(C)C
#  SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1752...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23525, dtype: object,
#  ID                                           CCCCCCCC/C=C/CCCCCC[C@@H](C)C(C)C
#  SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1752...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23526, dtype: object,
#  ID                                           CCCCCCCC/C=C/CCCCCC[C@@H](C)C(C)C
#  SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1752...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23527, dtype: object,
#  ID                                           CCCCCCCC/C=C/CCCCCC[C@@H](C)C(C)C
#  SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23528, dtype: object,
#  ID                                           CCCCCCCC/C=C/CCCCCC[C@@H](C)C(C)C
#  SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1752...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23529, dtype: object,
#  ID                                           CCCCCCCC/C=C/CCCCCC[C@@H](C)C(C)C
#  SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23530, dtype: object,
#  ID                                            CCCCCCCC/C=C/CCCCCC[C@H](C)C(C)C
#  SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23531, dtype: object,
#  ID                                            CCCCCCCC/C=C/CCCCCC[C@H](C)C(C)C
#  SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23532, dtype: object,
#  ID                                            CCCCCCCC/C=C/CCCCCC[C@H](C)C(C)C
#  SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23533, dtype: object,
#  ID                                            CCCCCCCC/C=C/CCCCCC[C@H](C)C(C)C
#  SMILES_nostereo                                     CCCCCCCCC=CCCCCCCC(C)C(C)C
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23534, dtype: object,
#  ID                                               CCCCCCCCCC[C@@H](C/C=C/C=O)OC
#  SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23575, dtype: object,
#  ID                                               CCCCCCCCCC[C@@H](C/C=C/C=O)OC
#  SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23576, dtype: object,
#  ID                                               CCCCCCCCCC[C@@H](C/C=C/C=O)OC
#  SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23577, dtype: object,
#  ID                                               CCCCCCCCCC[C@@H](C/C=C/C=O)OC
#  SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23578, dtype: object,
#  ID                                               CCCCCCCCCC[C@@H](C/C=C/C=O)OC
#  SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23579, dtype: object,
#  ID                                               CCCCCCCCCC[C@@H](C/C=C/C=O)OC
#  SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23580, dtype: object,
#  ID                                               CCCCCCCCCC[C@@H](C/C=C/C=O)OC
#  SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23581, dtype: object,
#  ID                                                CCCCCCCCCC[C@H](C/C=C/C=O)OC
#  SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23582, dtype: object,
#  ID                                                CCCCCCCCCC[C@H](C/C=C/C=O)OC
#  SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23583, dtype: object,
#  ID                                                CCCCCCCCCC[C@H](C/C=C/C=O)OC
#  SMILES_nostereo                                         CCCCCCCCCCC(CC=CC=O)OC
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1753...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23584, dtype: object,
#  ID                           CCCCCCCCN(CC[C@@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N...
#  SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23635, dtype: object,
#  ID                           CCCCCCCCN(CC[C@@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N...
#  SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23636, dtype: object,
#  ID                           CCCCCCCCN(CC[C@@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N...
#  SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23637, dtype: object,
#  ID                           CCCCCCCCN(CC[C@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N/...
#  SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23638, dtype: object,
#  ID                           CCCCCCCCN(CC[C@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N/...
#  SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23639, dtype: object,
#  ID                           CCCCCCCCN(CC[C@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N/...
#  SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23640, dtype: object,
#  ID                           CCCCCCCCN(CC[C@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N/...
#  SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23641, dtype: object,
#  ID                           CCCCCCCCN(CC[C@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N/...
#  SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23642, dtype: object,
#  ID                           CCCCCCCCN(CC[C@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N/...
#  SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23643, dtype: object,
#  ID                           CCCCCCCCN(CC[C@H]1CSC(SC(C)(C)C(O)O)=N1)/C1=N/...
#  SMILES_nostereo              CCCCCCCCN(CCC1CSC(SC(C)(C)C(O)O)=N1)C1=NC=C(N2...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#  RS_label                                                                     S
#  RS_label_binary                                                              1
#  Name: 23644, dtype: object,
#  ID                           CCCCCOc1ccc([C@@H]2/C(=C(\O)c3ccc4c(c3)OCCO4)C...
#  SMILES_nostereo              CCCCCOc1ccc(C2C(=C(O)c3ccc4c(c3)OCCO4)C(=O)C(=...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1754...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23855, dtype: object,
#  ID                           CCCCCOc1ccc([C@@H]2/C(=C(\O)c3ccc4c(c3)OCCO4)C...
#  SMILES_nostereo              CCCCCOc1ccc(C2C(=C(O)c3ccc4c(c3)OCCO4)C(=O)C(=...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1755...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23856, dtype: object,
#  ID                           CCCCCOc1ccc([C@@H]2/C(=C(\O)c3ccc4c(c3)OCCO4)C...
#  SMILES_nostereo              CCCCCOc1ccc(C2C(=C(O)c3ccc4c(c3)OCCO4)C(=O)C(=...
#  rdkit_mol_cistrans_stereo    <rdkit.Chem.rdchem.Mol object at 0x000001C1755...
#  RS_label                                                                     R
#  RS_label_binary                                                              0
#  Name: 23857, dtype: object,
#  ...]

# %%
import pandas as pd

# %%
type(filtered_list[0])
# Out:
# pandas.core.series.Series

# %%
filtered_list[0][1]
# Out:
# C:\Users\johan\AppData\Local\Temp\ipykernel_26252\812008273.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   filtered_list[0][1]
# 'C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)OCC)=C(c2ccccc2)N=3)cc1'

# %%
new_df = pd.DataFrame(filtered_list)
new_df
# Out:
#                                                       ID  \
# 506    C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 507    C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 508    C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 509    C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 510    C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# ...                                                  ...
# 69850  [N-]=[N+]=Nc1ccc(/C=C2\C=CC=C[C@H]2C(=O)c2cccc...
# 69851  [N-]=[N+]=Nc1ccc(/C=C2\C=CC=C[C@H]2C(=O)c2cccc...
# 69852  [N-]=[N+]=Nc1ccc(/C=C2\C=CC=C[C@H]2C(=O)c2cccc...
# 69853  [N-]=[N+]=Nc1ccc(/C=C2\C=CC=C[C@H]2C(=O)c2cccc...
# 69854  [N-]=[N+]=Nc1ccc(/C=C2\C=CC=C[C@H]2C(=O)c2cccc...
#
#                                          SMILES_nostereo  \
# 506    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# 507    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# 508    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# 509    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# 510    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# ...                                                  ...
# 69850     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
# 69851     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
# 69852     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
# 69853     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
# 69854     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
#
#                                rdkit_mol_cistrans_stereo RS_label  \
# 506    <rdkit.Chem.rdchem.Mol object at 0x000001C15E2...        S
# 507    <rdkit.Chem.rdchem.Mol object at 0x000001C138A...        S
# 508    <rdkit.Chem.rdchem.Mol object at 0x000001C15E2...        S
# 509    <rdkit.Chem.rdchem.Mol object at 0x000001C13FC...        S
# 510    <rdkit.Chem.rdchem.Mol object at 0x000001C13FC...        S
# ...                                                  ...      ...
# 69850  <rdkit.Chem.rdchem.Mol object at 0x000001C1220...        R
# 69851  <rdkit.Chem.rdchem.Mol object at 0x000001C1220...        R
# 69852  <rdkit.Chem.rdchem.Mol object at 0x000001C1220...        R
# 69853  <rdkit.Chem.rdchem.Mol object at 0x000001C1220...        R
# 69854  <rdkit.Chem.rdchem.Mol object at 0x000001C1220...        R
#
#        RS_label_binary
# 506                  1
# 507                  1
# 508                  1
# 509                  1
# 510                  1
# ...                ...
# 69850                0
# 69851                0
# 69852                0
# 69853                0
# 69854                0
#
# [3970 rows x 5 columns]

# %%
new_df.reset_index(drop='index', inplace=True)

# %% [markdown]
# ## Label generation is integrated into processing

# %%
new_df
# Out:
#                                                      ID  \
# 0     C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 1     C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 2     C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 3     C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 4     C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# ...                                                 ...
# 3965  [N-]=[N+]=Nc1ccc(/C=C2\C=CC=C[C@H]2C(=O)c2cccc...
# 3966  [N-]=[N+]=Nc1ccc(/C=C2\C=CC=C[C@H]2C(=O)c2cccc...
# 3967  [N-]=[N+]=Nc1ccc(/C=C2\C=CC=C[C@H]2C(=O)c2cccc...
# 3968  [N-]=[N+]=Nc1ccc(/C=C2\C=CC=C[C@H]2C(=O)c2cccc...
# 3969  [N-]=[N+]=Nc1ccc(/C=C2\C=CC=C[C@H]2C(=O)c2cccc...
#
#                                         SMILES_nostereo  \
# 0     C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# 1     C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# 2     C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# 3     C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# 4     C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# ...                                                 ...
# 3965     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
# 3966     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
# 3967     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
# 3968     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
# 3969     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
#
#                               rdkit_mol_cistrans_stereo RS_label  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x000001C15E2...        S
# 1     <rdkit.Chem.rdchem.Mol object at 0x000001C138A...        S
# 2     <rdkit.Chem.rdchem.Mol object at 0x000001C15E2...        S
# 3     <rdkit.Chem.rdchem.Mol object at 0x000001C13FC...        S
# 4     <rdkit.Chem.rdchem.Mol object at 0x000001C13FC...        S
# ...                                                 ...      ...
# 3965  <rdkit.Chem.rdchem.Mol object at 0x000001C1220...        R
# 3966  <rdkit.Chem.rdchem.Mol object at 0x000001C1220...        R
# 3967  <rdkit.Chem.rdchem.Mol object at 0x000001C1220...        R
# 3968  <rdkit.Chem.rdchem.Mol object at 0x000001C1220...        R
# 3969  <rdkit.Chem.rdchem.Mol object at 0x000001C1220...        R
#
#       RS_label_binary
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 3965                0
# 3966                0
# 3967                0
# 3968                0
# 3969                0
#
# [3970 rows x 5 columns]

# %% [markdown]
# ## Remove duplicate elements hailing from @/@@ i.e. R/S

# %%
def create_all_ez_isomers(df_entry):

    idx, entry = df_entry

    # fetch smiles string
    smiles = entry.ID

    # transform all to one sign
    smiles = smiles.replace("\\", "/")

    # split string
    split_smiles = smiles.split("/")

    # init new smiles
    new_smiles = [split_smiles[0]]

    for i in range(1, len(split_smiles)):
        # duplicate elements
        new_smiles = new_smiles * 2

        # append new content
        new_smiles[:int(len(new_smiles)/2)] = [
            elem + "/" + split_smiles[i]
            for elem in new_smiles[:int(len(new_smiles)/2)]
        ]
        new_smiles[int(len(new_smiles)/2):] = [
            elem + "\\" + split_smiles[i]
            for elem in new_smiles[int(len(new_smiles)/2):]
        ]

    return pd.DataFrame({
        "ID": new_smiles,
        "SMILES_nostereo": [entry['SMILES_nostereo']]*len(new_smiles)
    })

# %%
df_collection2 = pd.concat(list(map(create_all_ez_isomers, tqdm(new_df.iterrows(), total=len(new_df)))))
df_collection2.reset_index(inplace=True, drop='index')
df_collection2
# Out:
# 100%|██████████| 3970/3970 [00:00<00:00, 12743.22it/s]
#                                                       ID  \
# 0      C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 1      C#CCOc1ccc(\C=c2/sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 2      C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 3      C#CCOc1ccc(\C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 4      C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# ...                                                  ...
# 16515  [N-]=[N+]=Nc1ccc(\C=C2\C=CC=C[C@H]2C(=O)c2cccc...
# 16516  [N-]=[N+]=Nc1ccc(/C=C2/C=CC=C[C@H]2C(=O)c2cccc...
# 16517  [N-]=[N+]=Nc1ccc(\C=C2/C=CC=C[C@H]2C(=O)c2cccc...
# 16518  [N-]=[N+]=Nc1ccc(/C=C2\C=CC=C[C@H]2C(=O)c2cccc...
# 16519  [N-]=[N+]=Nc1ccc(\C=C2\C=CC=C[C@H]2C(=O)c2cccc...
#
#                                          SMILES_nostereo
# 0      C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# 1      C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# 2      C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# 3      C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# 4      C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# ...                                                  ...
# 16515     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
# 16516     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
# 16517     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
# 16518     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
# 16519     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
#
# [16520 rows x 2 columns]

# %%
# remove duplicates
df_collection2.drop_duplicates(subset=['ID', 'SMILES_nostereo'], inplace=True)
df_collection2
# Out:
#                                                       ID  \
# 0      C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 1      C#CCOc1ccc(\C=c2/sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 2      C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 3      C#CCOc1ccc(\C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 32     C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
# ...                                                  ...
# 16483  [N-]=[N+]=Nc1ccc(\C=C2\C=CC=C[C@@H]2C(=O)c2ccc...
# 16500  [N-]=[N+]=Nc1ccc(/C=C2/C=CC=C[C@H]2C(=O)c2cccc...
# 16501  [N-]=[N+]=Nc1ccc(\C=C2/C=CC=C[C@H]2C(=O)c2cccc...
# 16502  [N-]=[N+]=Nc1ccc(/C=C2\C=CC=C[C@H]2C(=O)c2cccc...
# 16503  [N-]=[N+]=Nc1ccc(\C=C2\C=CC=C[C@H]2C(=O)c2cccc...
#
#                                          SMILES_nostereo
# 0      C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# 1      C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# 2      C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# 3      C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# 32     C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
# ...                                                  ...
# 16483     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
# 16500     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
# 16501     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
# 16502     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
# 16503     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1
#
# [2404 rows x 2 columns]

# %%
# label molecules
def generate_labels(df_entry):
    from ptgnn.features.chienn.molecule3d import smiles_to_3d_mol
    from rdkit import Chem

    idx, entry = df_entry

    # render molecule
    molecule = smiles_to_3d_mol(entry.ID, max_number_of_atoms=100, max_number_of_attempts=100)

    if molecule is None:
        return None

    # iterate over label until the E/Z double bond is found.
    for bond in molecule.GetBonds():
        if bond.GetBondType() == Chem.rdchem.BondType.DOUBLE:
            if bond.GetStereo() == Chem.rdchem.BondStereo.STEREOE:
                entry['EZ_label'] = "E"
                entry['EZ_label_binary'] = 1
            elif bond.GetStereo() == Chem.rdchem.BondStereo.STEREOZ:
                entry['EZ_label'] = "Z"
                entry['EZ_label_binary'] = 0
            else:
                continue

    return entry

# %%
with Pool(processes=os.cpu_count()) as p:
    df_collection3 = list(p.imap(generate_labels, tqdm(df_collection2.iterrows(), total=len(df_collection2))))
df_collection3
# Out:
# 100%|██████████| 2404/2404 [00:50<00:00, 47.49it/s]
# [ID                 C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#  SMILES_nostereo    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 0, dtype: object,
#  ID                 C#CCOc1ccc(\C=c2/sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#  SMILES_nostereo    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 1, dtype: object,
#  ID                 C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#  SMILES_nostereo    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 2, dtype: object,
#  ID                 C#CCOc1ccc(\C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
#  SMILES_nostereo    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 3, dtype: object,
#  ID                 C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#  SMILES_nostereo    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 32, dtype: object,
#  ID                 C#CCOc1ccc(\C=c2/sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#  SMILES_nostereo    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 33, dtype: object,
#  ID                 C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#  SMILES_nostereo    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 34, dtype: object,
#  ID                 C#CCOc1ccc(\C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
#  SMILES_nostereo    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 35, dtype: object,
#  ID                 C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#  SMILES_nostereo    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 64, dtype: object,
#  ID                 C#CCOc1ccc(\C=c2/sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#  SMILES_nostereo    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 65, dtype: object,
#  ID                 C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#  SMILES_nostereo    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 66, dtype: object,
#  ID                 C#CCOc1ccc(\C=c2\sc3n(c2=O)[C@@H](c2cccc(OC)c2...
#  SMILES_nostereo    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 67, dtype: object,
#  ID                 C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#  SMILES_nostereo    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 100, dtype: object,
#  ID                 C#CCOc1ccc(\C=c2/sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#  SMILES_nostereo    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 101, dtype: object,
#  ID                 C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#  SMILES_nostereo    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 102, dtype: object,
#  ID                 C#CCOc1ccc(\C=c2\sc3n(c2=O)[C@H](c2cccc(OC)c2O...
#  SMILES_nostereo    C#CCOc1ccc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)C(C...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 103, dtype: object,
#  ID                 C#CCn1cc(/C=c2/sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#  SMILES_nostereo    C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 140, dtype: object,
#  ID                 C#CCn1cc(\C=c2/sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#  SMILES_nostereo    C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 141, dtype: object,
#  ID                 C#CCn1cc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#  SMILES_nostereo    C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 142, dtype: object,
#  ID                 C#CCn1cc(\C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2)C...
#  SMILES_nostereo    C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 143, dtype: object,
#  ID                 C#CCn1cc(/C=c2/sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#  SMILES_nostereo    C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 180, dtype: object,
#  ID                 C#CCn1cc(\C=c2/sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#  SMILES_nostereo    C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 181, dtype: object,
#  ID                 C#CCn1cc(/C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#  SMILES_nostereo    C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 182, dtype: object,
#  ID                 C#CCn1cc(\C=c2\sc3n(c2=O)[C@H](c2ccc(OC)cc2)C(...
#  SMILES_nostereo    C#CCn1cc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 183, dtype: object,
#  None,
#  None,
#  ID                 C1=CC=C([C@@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c...
#  SMILES_nostereo    C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 222, dtype: object,
#  None,
#  None,
#  ID                 C1=CC=C([C@@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c...
#  SMILES_nostereo    C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 225, dtype: object,
#  None,
#  None,
#  None,
#  None,
#  ID                 C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#  SMILES_nostereo    C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 238, dtype: object,
#  None,
#  None,
#  ID                 C1=CC=C([C@H]2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5...
#  SMILES_nostereo    C1=CC=C(C2C=C(c3cccc(-c4ccc5c6c(c7ccccc7c5c4)N...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 241, dtype: object,
#  None,
#  None,
#  ID                 C=C(C)/C(=C(N)/N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo    C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 300, dtype: object,
#  ID                 C=C(C)\C(=C(N)/N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo    C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 301, dtype: object,
#  ID                 C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo    C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 302, dtype: object,
#  ID                 C=C(C)\C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo    C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 303, dtype: object,
#  ID                 C=C(C)/C(=C(N)/N=C(\C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo    C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 304, dtype: object,
#  ID                 C=C(C)\C(=C(N)/N=C(\C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo    C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 305, dtype: object,
#  ID                 C=C(C)/C(=C(N)\N=C(\C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo    C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 306, dtype: object,
#  ID                 C=C(C)\C(=C(N)\N=C(\C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo    C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 307, dtype: object,
#  ID                 C=C(C)/C(=C(N)/N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo    C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 340, dtype: object,
#  ID                 C=C(C)\C(=C(N)/N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo    C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 341, dtype: object,
#  ID                 C=C(C)/C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo    C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 342, dtype: object,
#  ID                 C=C(C)\C(=C(N)\N=C(/C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo    C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 343, dtype: object,
#  ID                 C=C(C)/C(=C(N)/N=C(\C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo    C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 344, dtype: object,
#  ID                 C=C(C)\C(=C(N)/N=C(\C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo    C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 345, dtype: object,
#  ID                 C=C(C)/C(=C(N)\N=C(\C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo    C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 346, dtype: object,
#  ID                 C=C(C)\C(=C(N)\N=C(\C)C(=C)c1ccc(F)cc1NCc1cccc...
#  SMILES_nostereo    C=C(C)C(=C(N)N=C(C)C(=C)c1ccc(F)cc1NCc1ccccc1F...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 347, dtype: object,
#  ID                 C=C(/C=C/c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@@H](C...
#  SMILES_nostereo    C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 380, dtype: object,
#  ID                 C=C(\C=C/c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@@H](C...
#  SMILES_nostereo    C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 381, dtype: object,
#  ID                 C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@@H](C...
#  SMILES_nostereo    C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 382, dtype: object,
#  ID                 C=C(\C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@@H](C...
#  SMILES_nostereo    C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 383, dtype: object,
#  ID                 C=C(/C=C/c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#  SMILES_nostereo    C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 392, dtype: object,
#  ID                 C=C(\C=C/c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#  SMILES_nostereo    C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 393, dtype: object,
#  ID                 C=C(/C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#  SMILES_nostereo    C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 394, dtype: object,
#  ID                 C=C(\C=C\c1c(C)[nH]c(CC)c1NC(=O)c1ccc([C@H](CC...
#  SMILES_nostereo    C=C(C=Cc1c(C)[nH]c(CC)c1NC(=O)c1ccc(C(CCC)CCCC...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 395, dtype: object,
#  ID                 C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@@H]...
#  SMILES_nostereo         C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 420, dtype: object,
#  ID                 C=C(\C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@@H]...
#  SMILES_nostereo         C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 421, dtype: object,
#  ID                 C=C(/C=C\c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@@H]...
#  SMILES_nostereo         C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 422, dtype: object,
#  ID                 C=C(\C=C\c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@@H]...
#  SMILES_nostereo         C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 423, dtype: object,
#  ID                 C=C(/C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@H](...
#  SMILES_nostereo         C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 444, dtype: object,
#  ID                 C=C(\C=C/c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@H](...
#  SMILES_nostereo         C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 445, dtype: object,
#  ID                 C=C(/C=C\c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@H](...
#  SMILES_nostereo         C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 446, dtype: object,
#  ID                 C=C(\C=C\c1ccc(N(C)C)cc1)C(C)(C)c1ccccc1[C@H](...
#  SMILES_nostereo         C=C(C=Cc1ccc(N(C)C)cc1)C(C)(C)c1ccccc1C(C)CC
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 447, dtype: object,
#  ID                 C=C/C(=C/N[C@@](F)(P)CO)OC
#  SMILES_nostereo          C=CC(=CNC(F)(P)CO)OC
#  EZ_label                                    Z
#  EZ_label_binary                             0
#  Name: 460, dtype: object,
#  ID                 C=C\C(=C/N[C@@](F)(P)CO)OC
#  SMILES_nostereo          C=CC(=CNC(F)(P)CO)OC
#  EZ_label                                    E
#  EZ_label_binary                             1
#  Name: 461, dtype: object,
#  ID                 C=C/C(=C\N[C@@](F)(P)CO)OC
#  SMILES_nostereo          C=CC(=CNC(F)(P)CO)OC
#  EZ_label                                    E
#  EZ_label_binary                             1
#  Name: 462, dtype: object,
#  ID                 C=C\C(=C\N[C@@](F)(P)CO)OC
#  SMILES_nostereo          C=CC(=CNC(F)(P)CO)OC
#  EZ_label                                    Z
#  EZ_label_binary                             0
#  Name: 463, dtype: object,
#  ID                 C=C/C(=C/N[C@](F)(P)CO)OC
#  SMILES_nostereo         C=CC(=CNC(F)(P)CO)OC
#  EZ_label                                   Z
#  EZ_label_binary                            0
#  Name: 472, dtype: object,
#  ID                 C=C\C(=C/N[C@](F)(P)CO)OC
#  SMILES_nostereo         C=CC(=CNC(F)(P)CO)OC
#  EZ_label                                   E
#  EZ_label_binary                            1
#  Name: 473, dtype: object,
#  ID                 C=C/C(=C\N[C@](F)(P)CO)OC
#  SMILES_nostereo         C=CC(=CNC(F)(P)CO)OC
#  EZ_label                                   E
#  EZ_label_binary                            1
#  Name: 474, dtype: object,
#  ID                 C=C\C(=C\N[C@](F)(P)CO)OC
#  SMILES_nostereo         C=CC(=CNC(F)(P)CO)OC
#  EZ_label                                   Z
#  EZ_label_binary                            0
#  Name: 475, dtype: object,
#  ID                 C=C[C@@](C)(C#N)C/C=C/C
#  SMILES_nostereo          C=CC(C)(C#N)CC=CC
#  EZ_label                                 E
#  EZ_label_binary                          1
#  Name: 500, dtype: object,
#  ID                 C=C[C@@](C)(C#N)C\C=C/C
#  SMILES_nostereo          C=CC(C)(C#N)CC=CC
#  EZ_label                                 Z
#  EZ_label_binary                          0
#  Name: 501, dtype: object,
#  ID                 C=C[C@@](C)(C#N)C/C=C\C
#  SMILES_nostereo          C=CC(C)(C#N)CC=CC
#  EZ_label                                 Z
#  EZ_label_binary                          0
#  Name: 502, dtype: object,
#  ID                 C=C[C@@](C)(C#N)C\C=C\C
#  SMILES_nostereo          C=CC(C)(C#N)CC=CC
#  EZ_label                                 E
#  EZ_label_binary                          1
#  Name: 503, dtype: object,
#  ID                 C=C[C@](C)(C#N)C/C=C/C
#  SMILES_nostereo         C=CC(C)(C#N)CC=CC
#  EZ_label                                E
#  EZ_label_binary                         1
#  Name: 520, dtype: object,
#  ID                 C=C[C@](C)(C#N)C\C=C/C
#  SMILES_nostereo         C=CC(C)(C#N)CC=CC
#  EZ_label                                Z
#  EZ_label_binary                         0
#  Name: 521, dtype: object,
#  ID                 C=C[C@](C)(C#N)C/C=C\C
#  SMILES_nostereo         C=CC(C)(C#N)CC=CC
#  EZ_label                                Z
#  EZ_label_binary                         0
#  Name: 522, dtype: object,
#  ID                 C=C[C@](C)(C#N)C\C=C\C
#  SMILES_nostereo         C=CC(C)(C#N)CC=CC
#  EZ_label                                E
#  EZ_label_binary                         1
#  Name: 523, dtype: object,
#  ID                 C=C[C@@H](C)N(C)OC(C)(C)/C=C/O
#  SMILES_nostereo           C=CC(C)N(C)OC(C)(C)C=CO
#  EZ_label                                        E
#  EZ_label_binary                                 1
#  Name: 540, dtype: object,
#  ID                 C=C[C@@H](C)N(C)OC(C)(C)\C=C/O
#  SMILES_nostereo           C=CC(C)N(C)OC(C)(C)C=CO
#  EZ_label                                        Z
#  EZ_label_binary                                 0
#  Name: 541, dtype: object,
#  ID                 C=C[C@@H](C)N(C)OC(C)(C)/C=C\O
#  SMILES_nostereo           C=CC(C)N(C)OC(C)(C)C=CO
#  EZ_label                                        Z
#  EZ_label_binary                                 0
#  Name: 542, dtype: object,
#  ID                 C=C[C@@H](C)N(C)OC(C)(C)\C=C\O
#  SMILES_nostereo           C=CC(C)N(C)OC(C)(C)C=CO
#  EZ_label                                        E
#  EZ_label_binary                                 1
#  Name: 543, dtype: object,
#  ID                 C=C[C@H](C)N(C)OC(C)(C)/C=C/O
#  SMILES_nostereo          C=CC(C)N(C)OC(C)(C)C=CO
#  EZ_label                                       E
#  EZ_label_binary                                1
#  Name: 548, dtype: object,
#  ID                 C=C[C@H](C)N(C)OC(C)(C)\C=C/O
#  SMILES_nostereo          C=CC(C)N(C)OC(C)(C)C=CO
#  EZ_label                                       Z
#  EZ_label_binary                                0
#  Name: 549, dtype: object,
#  ID                 C=C[C@H](C)N(C)OC(C)(C)/C=C\O
#  SMILES_nostereo          C=CC(C)N(C)OC(C)(C)C=CO
#  EZ_label                                       Z
#  EZ_label_binary                                0
#  Name: 550, dtype: object,
#  ID                 C=C[C@H](C)N(C)OC(C)(C)\C=C\O
#  SMILES_nostereo          C=CC(C)N(C)OC(C)(C)C=CO
#  EZ_label                                       E
#  EZ_label_binary                                1
#  Name: 551, dtype: object,
#  ID                 C=C/C=C(/C=C)CNC[C@@H](C)N=C
#  SMILES_nostereo           C=CC=C(C=C)CNCC(C)N=C
#  EZ_label                                      Z
#  EZ_label_binary                               0
#  Name: 580, dtype: object,
#  ID                 C=C\C=C(/C=C)CNC[C@@H](C)N=C
#  SMILES_nostereo           C=CC=C(C=C)CNCC(C)N=C
#  EZ_label                                      E
#  EZ_label_binary                               1
#  Name: 581, dtype: object,
#  ID                 C=C/C=C(\C=C)CNC[C@@H](C)N=C
#  SMILES_nostereo           C=CC=C(C=C)CNCC(C)N=C
#  EZ_label                                      E
#  EZ_label_binary                               1
#  Name: 582, dtype: object,
#  ID                 C=C\C=C(\C=C)CNC[C@@H](C)N=C
#  SMILES_nostereo           C=CC=C(C=C)CNCC(C)N=C
#  EZ_label                                      Z
#  EZ_label_binary                               0
#  Name: 583, dtype: object,
#  ID                 C=C/C=C(/C=C)CNC[C@H](C)N=C
#  SMILES_nostereo          C=CC=C(C=C)CNCC(C)N=C
#  EZ_label                                     Z
#  EZ_label_binary                              0
#  Name: 600, dtype: object,
#  ID                 C=C\C=C(/C=C)CNC[C@H](C)N=C
#  SMILES_nostereo          C=CC=C(C=C)CNCC(C)N=C
#  EZ_label                                     E
#  EZ_label_binary                              1
#  Name: 601, dtype: object,
#  ID                 C=C/C=C(\C=C)CNC[C@H](C)N=C
#  SMILES_nostereo          C=CC=C(C=C)CNCC(C)N=C
#  EZ_label                                     E
#  EZ_label_binary                              1
#  Name: 602, dtype: object,
#  ID                 C=C\C=C(\C=C)CNC[C@H](C)N=C
#  SMILES_nostereo          C=CC=C(C=C)CNCC(C)N=C
#  EZ_label                                     Z
#  EZ_label_binary                              0
#  Name: 603, dtype: object,
#  ID                 C=C/C=C/[C@@H](C)C(=O)O
#  SMILES_nostereo           C=CC=CC(C)C(=O)O
#  EZ_label                                 E
#  EZ_label_binary                          1
#  Name: 620, dtype: object,
#  ID                 C=C\C=C/[C@@H](C)C(=O)O
#  SMILES_nostereo           C=CC=CC(C)C(=O)O
#  EZ_label                                 Z
#  EZ_label_binary                          0
#  Name: 621, dtype: object,
#  ID                 C=C/C=C\[C@@H](C)C(=O)O
#  SMILES_nostereo           C=CC=CC(C)C(=O)O
#  EZ_label                                 Z
#  EZ_label_binary                          0
#  Name: 622, dtype: object,
#  ID                 C=C\C=C\[C@@H](C)C(=O)O
#  SMILES_nostereo           C=CC=CC(C)C(=O)O
#  EZ_label                                 E
#  EZ_label_binary                          1
#  Name: 623, dtype: object,
#  ID                 C=C/C=C/[C@H](C)C(=O)O
#  SMILES_nostereo          C=CC=CC(C)C(=O)O
#  EZ_label                                E
#  EZ_label_binary                         1
#  Name: 644, dtype: object,
#  ID                 C=C\C=C/[C@H](C)C(=O)O
#  SMILES_nostereo          C=CC=CC(C)C(=O)O
#  EZ_label                                Z
#  EZ_label_binary                         0
#  Name: 645, dtype: object,
#  ID                 C=C/C=C\[C@H](C)C(=O)O
#  SMILES_nostereo          C=CC=CC(C)C(=O)O
#  EZ_label                                Z
#  EZ_label_binary                         0
#  Name: 646, dtype: object,
#  ID                 C=C\C=C\[C@H](C)C(=O)O
#  SMILES_nostereo          C=CC=CC(C)C(=O)O
#  EZ_label                                E
#  EZ_label_binary                         1
#  Name: 647, dtype: object,
#  ID                 C=CC[C@@H](C(=O)c1ccc(F)cc1)/C(=C/C=N)CC
#  SMILES_nostereo           C=CCC(C(=O)c1ccc(F)cc1)C(=CC=N)CC
#  EZ_label                                                  E
#  EZ_label_binary                                           1
#  Name: 660, dtype: object,
#  ID                 C=CC[C@@H](C(=O)c1ccc(F)cc1)\C(=C/C=N)CC
#  SMILES_nostereo           C=CCC(C(=O)c1ccc(F)cc1)C(=CC=N)CC
#  EZ_label                                                  Z
#  EZ_label_binary                                           0
#  Name: 661, dtype: object,
#  ID                 C=CC[C@@H](C(=O)c1ccc(F)cc1)/C(=C\C=N)CC
#  SMILES_nostereo           C=CCC(C(=O)c1ccc(F)cc1)C(=CC=N)CC
#  EZ_label                                                  Z
#  EZ_label_binary                                           0
#  Name: 662, dtype: object,
#  ID                 C=CC[C@@H](C(=O)c1ccc(F)cc1)\C(=C\C=N)CC
#  SMILES_nostereo           C=CCC(C(=O)c1ccc(F)cc1)C(=CC=N)CC
#  EZ_label                                                  E
#  EZ_label_binary                                           1
#  Name: 663, dtype: object,
#  ID                 C=CC[C@H](C(=O)c1ccc(F)cc1)/C(=C/C=N)CC
#  SMILES_nostereo          C=CCC(C(=O)c1ccc(F)cc1)C(=CC=N)CC
#  EZ_label                                                 E
#  EZ_label_binary                                          1
#  Name: 668, dtype: object,
#  ID                 C=CC[C@H](C(=O)c1ccc(F)cc1)\C(=C/C=N)CC
#  SMILES_nostereo          C=CCC(C(=O)c1ccc(F)cc1)C(=CC=N)CC
#  EZ_label                                                 Z
#  EZ_label_binary                                          0
#  Name: 669, dtype: object,
#  ID                 C=CC[C@H](C(=O)c1ccc(F)cc1)/C(=C\C=N)CC
#  SMILES_nostereo          C=CCC(C(=O)c1ccc(F)cc1)C(=CC=N)CC
#  EZ_label                                                 Z
#  EZ_label_binary                                          0
#  Name: 670, dtype: object,
#  ID                 C=CC[C@H](C(=O)c1ccc(F)cc1)\C(=C\C=N)CC
#  SMILES_nostereo          C=CCC(C(=O)c1ccc(F)cc1)C(=CC=N)CC
#  EZ_label                                                 E
#  EZ_label_binary                                          1
#  Name: 671, dtype: object,
#  ID                 C=CCN1C(=O)C(C#N)=C(C)/C(=C/c2cn(-c3ccccc3)nc2...
#  SMILES_nostereo    C=CCN1C(=O)C(=Cc2cn(-c3ccccc3)nc2-c2cccc(S(=O)...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 700, dtype: object,
#  ID                 C=CCN1C(=O)C(C#N)=C(C)\C(=C/c2cn(-c3ccccc3)nc2...
#  SMILES_nostereo    C=CCN1C(=O)C(=Cc2cn(-c3ccccc3)nc2-c2cccc(S(=O)...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 701, dtype: object,
#  ID                 C=CCN1C(=O)C(C#N)=C(C)/C(=C\c2cn(-c3ccccc3)nc2...
#  SMILES_nostereo    C=CCN1C(=O)C(=Cc2cn(-c3ccccc3)nc2-c2cccc(S(=O)...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 702, dtype: object,
#  ID                 C=CCN1C(=O)C(C#N)=C(C)\C(=C\c2cn(-c3ccccc3)nc2...
#  SMILES_nostereo    C=CCN1C(=O)C(=Cc2cn(-c3ccccc3)nc2-c2cccc(S(=O)...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 703, dtype: object,
#  ID                 C=CCN1C(=O)C(C#N)=C(C)/C(=C/c2cn(-c3ccccc3)nc2...
#  SMILES_nostereo    C=CCN1C(=O)C(=Cc2cn(-c3ccccc3)nc2-c2cccc(S(=O)...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 732, dtype: object,
#  ID                 C=CCN1C(=O)C(C#N)=C(C)\C(=C/c2cn(-c3ccccc3)nc2...
#  SMILES_nostereo    C=CCN1C(=O)C(=Cc2cn(-c3ccccc3)nc2-c2cccc(S(=O)...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 733, dtype: object,
#  ID                 C=CCN1C(=O)C(C#N)=C(C)/C(=C\c2cn(-c3ccccc3)nc2...
#  SMILES_nostereo    C=CCN1C(=O)C(=Cc2cn(-c3ccccc3)nc2-c2cccc(S(=O)...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 734, dtype: object,
#  ID                 C=CCN1C(=O)C(C#N)=C(C)\C(=C\c2cn(-c3ccccc3)nc2...
#  SMILES_nostereo    C=CCN1C(=O)C(=Cc2cn(-c3ccccc3)nc2-c2cccc(S(=O)...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 735, dtype: object,
#  ID                 C=CCN1C(=O)[C@@]2(/C(=C(/O)c3ccc(OCCC)cc3)C(=O...
#  SMILES_nostereo    C=CCN1C(=O)C2(C(=C(O)c3ccc(OCCC)cc3)C(=O)C(=O)...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 740, dtype: object,
#  ID                 C=CCN1C(=O)[C@@]2(\C(=C(/O)c3ccc(OCCC)cc3)C(=O...
#  SMILES_nostereo    C=CCN1C(=O)C2(C(=C(O)c3ccc(OCCC)cc3)C(=O)C(=O)...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 741, dtype: object,
#  ID                 C=CCN1C(=O)[C@@]2(/C(=C(\O)c3ccc(OCCC)cc3)C(=O...
#  SMILES_nostereo    C=CCN1C(=O)C2(C(=C(O)c3ccc(OCCC)cc3)C(=O)C(=O)...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 742, dtype: object,
#  ID                 C=CCN1C(=O)[C@@]2(\C(=C(\O)c3ccc(OCCC)cc3)C(=O...
#  SMILES_nostereo    C=CCN1C(=O)C2(C(=C(O)c3ccc(OCCC)cc3)C(=O)C(=O)...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 743, dtype: object,
#  ID                 C=CCN1C(=O)[C@]2(/C(=C(/O)c3ccc(OCCC)cc3)C(=O)...
#  SMILES_nostereo    C=CCN1C(=O)C2(C(=C(O)c3ccc(OCCC)cc3)C(=O)C(=O)...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 780, dtype: object,
#  ID                 C=CCN1C(=O)[C@]2(\C(=C(/O)c3ccc(OCCC)cc3)C(=O)...
#  SMILES_nostereo    C=CCN1C(=O)C2(C(=C(O)c3ccc(OCCC)cc3)C(=O)C(=O)...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 781, dtype: object,
#  ID                 C=CCN1C(=O)[C@]2(/C(=C(\O)c3ccc(OCCC)cc3)C(=O)...
#  SMILES_nostereo    C=CCN1C(=O)C2(C(=C(O)c3ccc(OCCC)cc3)C(=O)C(=O)...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 782, dtype: object,
#  ID                 C=CCN1C(=O)[C@]2(\C(=C(\O)c3ccc(OCCC)cc3)C(=O)...
#  SMILES_nostereo    C=CCN1C(=O)C2(C(=C(O)c3ccc(OCCC)cc3)C(=O)C(=O)...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 783, dtype: object,
#  ID                 C=CCNC(=O)[C@@H](C)OC(=O)/C(C#N)=C/c1cc(C)n(-c...
#  SMILES_nostereo    C=CCNC(=O)C(C)OC(=O)C(C#N)=Cc1cc(C)n(-c2ccccc2...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 820, dtype: object,
#  ID                 C=CCNC(=O)[C@@H](C)OC(=O)\C(C#N)=C/c1cc(C)n(-c...
#  SMILES_nostereo    C=CCNC(=O)C(C)OC(=O)C(C#N)=Cc1cc(C)n(-c2ccccc2...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 821, dtype: object,
#  ID                 C=CCNC(=O)[C@@H](C)OC(=O)/C(C#N)=C\c1cc(C)n(-c...
#  SMILES_nostereo    C=CCNC(=O)C(C)OC(=O)C(C#N)=Cc1cc(C)n(-c2ccccc2...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 822, dtype: object,
#  ID                 C=CCNC(=O)[C@@H](C)OC(=O)\C(C#N)=C\c1cc(C)n(-c...
#  SMILES_nostereo    C=CCNC(=O)C(C)OC(=O)C(C#N)=Cc1cc(C)n(-c2ccccc2...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 823, dtype: object,
#  ID                 C=CCNC(=O)[C@H](C)OC(=O)/C(C#N)=C/c1cc(C)n(-c2...
#  SMILES_nostereo    C=CCNC(=O)C(C)OC(=O)C(C#N)=Cc1cc(C)n(-c2ccccc2...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 860, dtype: object,
#  ID                 C=CCNC(=O)[C@H](C)OC(=O)\C(C#N)=C/c1cc(C)n(-c2...
#  SMILES_nostereo    C=CCNC(=O)C(C)OC(=O)C(C#N)=Cc1cc(C)n(-c2ccccc2...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 861, dtype: object,
#  ID                 C=CCNC(=O)[C@H](C)OC(=O)/C(C#N)=C\c1cc(C)n(-c2...
#  SMILES_nostereo    C=CCNC(=O)C(C)OC(=O)C(C#N)=Cc1cc(C)n(-c2ccccc2...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 862, dtype: object,
#  ID                 C=CCNC(=O)[C@H](C)OC(=O)\C(C#N)=C\c1cc(C)n(-c2...
#  SMILES_nostereo    C=CCNC(=O)C(C)OC(=O)C(C#N)=Cc1cc(C)n(-c2ccccc2...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 863, dtype: object,
#  ID                 C=CCOc1c(I)cc(/C=c2/sc3n(c2=O)[C@@H](c2cccc(OC...
#  SMILES_nostereo    C=CCOc1c(I)cc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 900, dtype: object,
#  ID                 C=CCOc1c(I)cc(\C=c2/sc3n(c2=O)[C@@H](c2cccc(OC...
#  SMILES_nostereo    C=CCOc1c(I)cc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 901, dtype: object,
#  ID                 C=CCOc1c(I)cc(/C=c2\sc3n(c2=O)[C@@H](c2cccc(OC...
#  SMILES_nostereo    C=CCOc1c(I)cc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 902, dtype: object,
#  ID                 C=CCOc1c(I)cc(\C=c2\sc3n(c2=O)[C@@H](c2cccc(OC...
#  SMILES_nostereo    C=CCOc1c(I)cc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 903, dtype: object,
#  ID                 C=CCOc1c(I)cc(/C=c2/sc3n(c2=O)[C@H](c2cccc(OC)...
#  SMILES_nostereo    C=CCOc1c(I)cc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 924, dtype: object,
#  ID                 C=CCOc1c(I)cc(\C=c2/sc3n(c2=O)[C@H](c2cccc(OC)...
#  SMILES_nostereo    C=CCOc1c(I)cc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 925, dtype: object,
#  ID                 C=CCOc1c(I)cc(/C=c2\sc3n(c2=O)[C@H](c2cccc(OC)...
#  SMILES_nostereo    C=CCOc1c(I)cc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 926, dtype: object,
#  ID                 C=CCOc1c(I)cc(\C=c2\sc3n(c2=O)[C@H](c2cccc(OC)...
#  SMILES_nostereo    C=CCOc1c(I)cc(C=c2sc3n(c2=O)C(c2cccc(OC)c2OCC)...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 927, dtype: object,
#  ID                 C=CCOc1ccc(/C=C(/C#N)C(=O)NC[C@@H]2CCCO2)cc1OC
#  SMILES_nostereo           C=CCOc1ccc(C=C(C#N)C(=O)NCC2CCCO2)cc1OC
#  EZ_label                                                        Z
#  EZ_label_binary                                                 0
#  Name: 952, dtype: object,
#  ID                 C=CCOc1ccc(\C=C(/C#N)C(=O)NC[C@@H]2CCCO2)cc1OC
#  SMILES_nostereo           C=CCOc1ccc(C=C(C#N)C(=O)NCC2CCCO2)cc1OC
#  EZ_label                                                        E
#  EZ_label_binary                                                 1
#  Name: 953, dtype: object,
#  ID                 C=CCOc1ccc(/C=C(\C#N)C(=O)NC[C@@H]2CCCO2)cc1OC
#  SMILES_nostereo           C=CCOc1ccc(C=C(C#N)C(=O)NCC2CCCO2)cc1OC
#  EZ_label                                                        E
#  EZ_label_binary                                                 1
#  Name: 954, dtype: object,
#  ID                 C=CCOc1ccc(\C=C(\C#N)C(=O)NC[C@@H]2CCCO2)cc1OC
#  SMILES_nostereo           C=CCOc1ccc(C=C(C#N)C(=O)NCC2CCCO2)cc1OC
#  EZ_label                                                        Z
#  EZ_label_binary                                                 0
#  Name: 955, dtype: object,
#  ID                 C=CCOc1ccc(/C=C(/C#N)C(=O)NC[C@H]2CCCO2)cc1OC
#  SMILES_nostereo          C=CCOc1ccc(C=C(C#N)C(=O)NCC2CCCO2)cc1OC
#  EZ_label                                                       Z
#  EZ_label_binary                                                0
#  Name: 992, dtype: object,
#  ID                 C=CCOc1ccc(\C=C(/C#N)C(=O)NC[C@H]2CCCO2)cc1OC
#  SMILES_nostereo          C=CCOc1ccc(C=C(C#N)C(=O)NCC2CCCO2)cc1OC
#  EZ_label                                                       E
#  EZ_label_binary                                                1
#  Name: 993, dtype: object,
#  ID                 C=CCOc1ccc(/C=C(\C#N)C(=O)NC[C@H]2CCCO2)cc1OC
#  SMILES_nostereo          C=CCOc1ccc(C=C(C#N)C(=O)NCC2CCCO2)cc1OC
#  EZ_label                                                       E
#  EZ_label_binary                                                1
#  Name: 994, dtype: object,
#  ID                 C=CCOc1ccc(\C=C(\C#N)C(=O)NC[C@H]2CCCO2)cc1OC
#  SMILES_nostereo          C=CCOc1ccc(C=C(C#N)C(=O)NCC2CCCO2)cc1OC
#  EZ_label                                                       Z
#  EZ_label_binary                                                0
#  Name: 995, dtype: object,
#  ID                 C=CCc1c(/C=C/C)sc2c1=CC=C[C@@](C)(c1ccccc1)C=2
#  SMILES_nostereo          C=CCc1c(C=CC)sc2c1=CC=CC(C)(c1ccccc1)C=2
#  EZ_label                                                        E
#  EZ_label_binary                                                 1
#  Name: 1032, dtype: object,
#  ID                 C=CCc1c(\C=C/C)sc2c1=CC=C[C@@](C)(c1ccccc1)C=2
#  SMILES_nostereo          C=CCc1c(C=CC)sc2c1=CC=CC(C)(c1ccccc1)C=2
#  EZ_label                                                        Z
#  EZ_label_binary                                                 0
#  Name: 1033, dtype: object,
#  ID                 C=CCc1c(/C=C\C)sc2c1=CC=C[C@@](C)(c1ccccc1)C=2
#  SMILES_nostereo          C=CCc1c(C=CC)sc2c1=CC=CC(C)(c1ccccc1)C=2
#  EZ_label                                                        Z
#  EZ_label_binary                                                 0
#  Name: 1034, dtype: object,
#  ID                 C=CCc1c(\C=C\C)sc2c1=CC=C[C@@](C)(c1ccccc1)C=2
#  SMILES_nostereo          C=CCc1c(C=CC)sc2c1=CC=CC(C)(c1ccccc1)C=2
#  EZ_label                                                        E
#  EZ_label_binary                                                 1
#  Name: 1035, dtype: object,
#  ID                 C=CCc1c(/C=C/C)sc2c1=CC=C[C@](C)(c1ccccc1)C=2
#  SMILES_nostereo         C=CCc1c(C=CC)sc2c1=CC=CC(C)(c1ccccc1)C=2
#  EZ_label                                                       E
#  EZ_label_binary                                                1
#  Name: 1052, dtype: object,
#  ID                 C=CCc1c(\C=C/C)sc2c1=CC=C[C@](C)(c1ccccc1)C=2
#  SMILES_nostereo         C=CCc1c(C=CC)sc2c1=CC=CC(C)(c1ccccc1)C=2
#  EZ_label                                                       Z
#  EZ_label_binary                                                0
#  Name: 1053, dtype: object,
#  ID                 C=CCc1c(/C=C\C)sc2c1=CC=C[C@](C)(c1ccccc1)C=2
#  SMILES_nostereo         C=CCc1c(C=CC)sc2c1=CC=CC(C)(c1ccccc1)C=2
#  EZ_label                                                       Z
#  EZ_label_binary                                                0
#  Name: 1054, dtype: object,
#  ID                 C=CCc1c(\C=C\C)sc2c1=CC=C[C@](C)(c1ccccc1)C=2
#  SMILES_nostereo         C=CCc1c(C=CC)sc2c1=CC=CC(C)(c1ccccc1)C=2
#  EZ_label                                                       E
#  EZ_label_binary                                                1
#  Name: 1055, dtype: object,
#  ID                 C=CNc1cccc(/C=C/Nc2c([C@@H]3CN(c4ccc(F)c5c4Cc4...
#  SMILES_nostereo    C=CNc1cccc(C=CNc2c(C3CN(c4ccc(F)c5c4Cc4ccccc4-...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 1072, dtype: object,
#  ID                 C=CNc1cccc(\C=C/Nc2c([C@@H]3CN(c4ccc(F)c5c4Cc4...
#  SMILES_nostereo    C=CNc1cccc(C=CNc2c(C3CN(c4ccc(F)c5c4Cc4ccccc4-...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 1073, dtype: object,
#  ID                 C=CNc1cccc(/C=C\Nc2c([C@@H]3CN(c4ccc(F)c5c4Cc4...
#  SMILES_nostereo    C=CNc1cccc(C=CNc2c(C3CN(c4ccc(F)c5c4Cc4ccccc4-...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 1074, dtype: object,
#  ID                 C=CNc1cccc(\C=C\Nc2c([C@@H]3CN(c4ccc(F)c5c4Cc4...
#  SMILES_nostereo    C=CNc1cccc(C=CNc2c(C3CN(c4ccc(F)c5c4Cc4ccccc4-...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 1075, dtype: object,
#  ID                 C=CNc1cccc(/C=C/Nc2c([C@H]3CN(c4ccc(F)c5c4Cc4c...
#  SMILES_nostereo    C=CNc1cccc(C=CNc2c(C3CN(c4ccc(F)c5c4Cc4ccccc4-...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 1100, dtype: object,
#  ID                 C=CNc1cccc(\C=C/Nc2c([C@H]3CN(c4ccc(F)c5c4Cc4c...
#  SMILES_nostereo    C=CNc1cccc(C=CNc2c(C3CN(c4ccc(F)c5c4Cc4ccccc4-...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 1101, dtype: object,
#  ID                 C=CNc1cccc(/C=C\Nc2c([C@H]3CN(c4ccc(F)c5c4Cc4c...
#  SMILES_nostereo    C=CNc1cccc(C=CNc2c(C3CN(c4ccc(F)c5c4Cc4ccccc4-...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 1102, dtype: object,
#  ID                 C=CNc1cccc(\C=C\Nc2c([C@H]3CN(c4ccc(F)c5c4Cc4c...
#  SMILES_nostereo    C=CNc1cccc(C=CNc2c(C3CN(c4ccc(F)c5c4Cc4ccccc4-...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 1103, dtype: object,
#  ID                 C=c1[nH]n(-c2ccccc2)c(=O)/c1=C/N(C(=O)[C@@H]1C...
#  SMILES_nostereo    C=c1[nH]n(-c2ccccc2)c(=O)c1=CN(C(=O)C1CCCN1C(=...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 1112, dtype: object,
#  ID                 C=c1[nH]n(-c2ccccc2)c(=O)\c1=C/N(C(=O)[C@@H]1C...
#  SMILES_nostereo    C=c1[nH]n(-c2ccccc2)c(=O)c1=CN(C(=O)C1CCCN1C(=...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 1113, dtype: object,
#  ID                 C=c1[nH]n(-c2ccccc2)c(=O)/c1=C\N(C(=O)[C@@H]1C...
#  SMILES_nostereo    C=c1[nH]n(-c2ccccc2)c(=O)c1=CN(C(=O)C1CCCN1C(=...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 1114, dtype: object,
#  ID                 C=c1[nH]n(-c2ccccc2)c(=O)\c1=C\N(C(=O)[C@@H]1C...
#  SMILES_nostereo    C=c1[nH]n(-c2ccccc2)c(=O)c1=CN(C(=O)C1CCCN1C(=...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 1115, dtype: object,
#  ID                 C=c1[nH]n(-c2ccccc2)c(=O)/c1=C/N(C(=O)[C@H]1CC...
#  SMILES_nostereo    C=c1[nH]n(-c2ccccc2)c(=O)c1=CN(C(=O)C1CCCN1C(=...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 1132, dtype: object,
#  ID                 C=c1[nH]n(-c2ccccc2)c(=O)\c1=C/N(C(=O)[C@H]1CC...
#  SMILES_nostereo    C=c1[nH]n(-c2ccccc2)c(=O)c1=CN(C(=O)C1CCCN1C(=...
#  EZ_label                                                           Z
# ...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(Br)c(OCc4ccc([N+]...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 5868, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C/c3cc(Br)c(OCc4ccc([N...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(Br)c(OCc4ccc([N+]...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 5869, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C\c3cc(Br)c(OCc4ccc([N...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(Br)c(OCc4ccc([N+]...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 5870, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C\c3cc(Br)c(OCc4ccc([N...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(Br)c(OCc4ccc([N+]...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 5871, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C/c3cc(Br)c(OCc4ccc([N...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(Br)c(OCc4ccc([N+]...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 5896, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C/c3cc(Br)c(OCc4ccc([N...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(Br)c(OCc4ccc([N+]...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 5897, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C\c3cc(Br)c(OCc4ccc([N...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(Br)c(OCc4ccc([N+]...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 5898, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C\c3cc(Br)c(OCc4ccc([N...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(Br)c(OCc4ccc([N+]...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 5899, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C/c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 5928, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C/c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 5929, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C\c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 5930, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C\c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 5931, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C/c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 5968, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C/c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 5969, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C\c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 5970, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C\c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 5971, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C/c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6008, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C/c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6009, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C\c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6010, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C\c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6011, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C/c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6048, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C/c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6049, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C\c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6050, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C\c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6051, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C/c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6088, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C/c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6089, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C\c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6090, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C\c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6091, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C/c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6128, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C/c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6129, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C\c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6130, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C\c3cc(C)n(-c4ccc(C(=O...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C(=O)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6131, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C/c3cc(C)n(-c4ccc(C)c(...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C)c(C)...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6168, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C/c3cc(C)n(-c4ccc(C)c(...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C)c(C)...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6169, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C\c3cc(C)n(-c4ccc(C)c(...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C)c(C)...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6170, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C\c3cc(C)n(-c4ccc(C)c(...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C)c(C)...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6171, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C/c3cc(C)n(-c4ccc(C)c(...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C)c(C)...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6208, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C/c3cc(C)n(-c4ccc(C)c(...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C)c(C)...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6209, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C\c3cc(C)n(-c4ccc(C)c(...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C)c(C)...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6210, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C\c3cc(C)n(-c4ccc(C)c(...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc(C)c(C)...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6211, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C/c3cc(C)n(-c4ccc5c(c4...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc5c(c4)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6248, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C/c3cc(C)n(-c4ccc5c(c4...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc5c(c4)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6249, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C\c3cc(C)n(-c4ccc5c(c4...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc5c(c4)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6250, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C\c3cc(C)n(-c4ccc5c(c4...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc5c(c4)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6251, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C/c3cc(C)n(-c4ccc5c(c4...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc5c(c4)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6288, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C/c3cc(C)n(-c4ccc5c(c4...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc5c(c4)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6289, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C\c3cc(C)n(-c4ccc5c(c4...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc5c(c4)O...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6290, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C\c3cc(C)n(-c4ccc5c(c4...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4ccc5c(c4)O...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6291, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C/c3cc(C)n(-c4cccc(Cl)...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4cccc(Cl)c4...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6328, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C/c3cc(C)n(-c4cccc(Cl)...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4cccc(Cl)c4...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6329, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s/c(=C\c3cc(C)n(-c4cccc(Cl)...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4cccc(Cl)c4...
#  EZ_label                                                           Z
#  EZ_label_binary                                                    0
#  Name: 6330, dtype: object,
#  ID                 CCOC(=O)C1=C(C)N=c2s\c(=C\c3cc(C)n(-c4cccc(Cl)...
#  SMILES_nostereo    CCOC(=O)C1=C(C)N=c2sc(=Cc3cc(C)n(-c4cccc(Cl)c4...
#  EZ_label                                                           E
#  EZ_label_binary                                                    1
#  Name: 6331, dtype: object,
#  ...]

# %%
df_collection3 = pd.DataFrame([elem for elem in df_collection3 if elem is not None])
df_collection3
# Out:
#                                                       ID  \
# 0      C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 1      C#CCOc1ccc(\C=c2/sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 2      C#CCOc1ccc(/C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 3      C#CCOc1ccc(\C=c2\sc3n(c2=O)[C@@H](c2ccc(OC)cc2...
# 32     C#CCOc1ccc(/C=c2/sc3n(c2=O)[C@H](c2ccc(OC)cc2)...
# ...                                                  ...
# 16483  [N-]=[N+]=Nc1ccc(\C=C2\C=CC=C[C@@H]2C(=O)c2ccc...
# 16500  [N-]=[N+]=Nc1ccc(/C=C2/C=CC=C[C@H]2C(=O)c2cccc...
# 16501  [N-]=[N+]=Nc1ccc(\C=C2/C=CC=C[C@H]2C(=O)c2cccc...
# 16502  [N-]=[N+]=Nc1ccc(/C=C2\C=CC=C[C@H]2C(=O)c2cccc...
# 16503  [N-]=[N+]=Nc1ccc(\C=C2\C=CC=C[C@H]2C(=O)c2cccc...
#
#                                          SMILES_nostereo EZ_label  \
# 0      C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...        E
# 1      C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...        Z
# 2      C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...        Z
# 3      C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...        E
# 32     C#CCOc1ccc(C=c2sc3n(c2=O)C(c2ccc(OC)cc2)C(C(=O...        E
# ...                                                  ...      ...
# 16483     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1        Z
# 16500     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1        Z
# 16501     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1        E
# 16502     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1        E
# 16503     [N-]=[N+]=Nc1ccc(C=C2C=CC=CC2C(=O)c2ccccc2)cc1        Z
#
#        EZ_label_binary
# 0                    1
# 1                    0
# 2                    0
# 3                    1
# 32                   1
# ...                ...
# 16483                0
# 16500                0
# 16501                1
# 16502                1
# 16503                0
#
# [2374 rows x 4 columns]

# %% [markdown]
# # Import finalized dataset

# %%
from ptgnn.dataset.ez_dataset import EZDataset

# %%
val_ds = EZDataset(root="hyperoptimization/src/ez", split='val')
# Out:
# Processing...
# Split: val: 100%|██████████| 2374/2374 [00:36<00:00, 64.87it/s]
# Done!

# %%
test_ds = EZDataset(root="hyperoptimization/src/ez", split='test')
# Out:
# Starting download and dataset generation for split: test
# test: filter: 100%|██████████| 11680/11680 [00:57<00:00, 204.51it/s]
# test: isomer creation: 100%|██████████| 606/606 [00:08<00:00, 73.29it/s]
# test: label generation: 100%|██████████| 2640/2640 [00:28<00:00, 93.52it/s]
# Done!
# Processing...
# Split: test: 100%|██████████| 2640/2640 [00:39<00:00, 66.26it/s]
# Done!

# %%
train_ds = EZDataset(root="hyperoptimization/src/ez", split='train')
# Out:
# Starting download and dataset generation for split: train
# train: filter: 100%|██████████| 55084/55084 [04:22<00:00, 209.84it/s]
# train: isomer creation: 100%|██████████| 2804/2804 [00:11<00:00, 242.96it/s]
# train: label generation: 100%|██████████| 11808/11808 [02:03<00:00, 95.71it/s]
# Done!
# Processing...
# Split: train: 100%|██████████| 11784/11784 [02:23<00:00, 82.23it/s]
# Done!

# %%
for elem in val_ds:
    display(elem)
    break
# Out:
# Data(x=[140, 118], edge_index=[2, 370], edge_attr=[370, 80], pos=[140, 6], parallel_node_index=[140], circle_index=[140], y=[1])

# %%
elem.y
# Out:
# tensor([1])
