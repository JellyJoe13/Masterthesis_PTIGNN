# %%
from rdkit import Chem
from rdkit.Chem import Draw

# %%
smiles = "OC[C@@](O)([H])[C@@]([H])(O)C=O"
smiles = "C/N=N\CO"
smiles = "ClC[C@](CO)(CBr)CN"
mol = Chem.MolFromSmiles(smiles)
mol = Chem.AddHs(mol)

# %%
img = Draw.MolToImage(mol)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
file_path = "D:/DATEN/Latex/Masterarbeit/figures/molecules/cistrans_nitrogen2.png"
file_path = "D:/DATEN/Latex/Masterarbeit/figures/molecules/minimal_stereo_tree.png"

img.save(file_path)
